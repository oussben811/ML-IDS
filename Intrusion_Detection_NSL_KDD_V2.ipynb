# %% [markdown]
# # **Data Preprocessing**

# %%
pip install --upgrade scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 56.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# Successfully installed scikit-learn-1.5.0

# %%
# importing required libraries
import numpy as np
import pandas as pd

import pickle # saving and loading trained model
from os import path

# importing required libraries for normalizing data
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# importing library for plotting
import matplotlib.pyplot as plt

# importing library for support vector machine classifier
from sklearn.svm import SVC
# importing library for K-neares-neighbor classifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier  # Import Random Forest classifier


from sklearn import metrics
from sklearn.metrics import accuracy_score # for calculating accuracy of model
from sklearn.model_selection import train_test_split # for splitting the dataset for training and testing
from sklearn.metrics import classification_report # for generating a classification report of model

from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc

from keras.layers import Dense # importing dense layer
from keras.models import Sequential #importing Sequential layer
from keras.models import model_from_json # saving and loading trained model

from keras.layers import LSTM
from keras.layers import Input
from keras.models import Model

# representation of model layers
from keras.utils import plot_model

# %%
# dataset doesn't have column names, so we have to provide it
col_names = ["duration","protocol_type","service","flag","src_bytes",
    "dst_bytes","land","wrong_fragment","urgent","hot","num_failed_logins",
    "logged_in","num_compromised","root_shell","su_attempted","num_root",
    "num_file_creations","num_shells","num_access_files","num_outbound_cmds",
    "is_host_login","is_guest_login","count","srv_count","serror_rate",
    "srv_serror_rate","rerror_rate","srv_rerror_rate","same_srv_rate",
    "diff_srv_rate","srv_diff_host_rate","dst_host_count","dst_host_srv_count",
    "dst_host_same_srv_rate","dst_host_diff_srv_rate","dst_host_same_src_port_rate",
    "dst_host_srv_diff_host_rate","dst_host_serror_rate","dst_host_srv_serror_rate",
    "dst_host_rerror_rate","dst_host_srv_rerror_rate","label","difficulty_level"]

# %%
# importing dataset
data = pd.read_csv('datasets/KDDTrain+.txt',header=None, names=col_names)
#data = pd.read_csv('datasets/KDDTrain+.txt',header=None, names=col_names)

# %%
# print dataset
data
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0              0           tcp  ftp_data   SF        491          0     0
# 1              0           udp     other   SF        146          0     0
# 2              0           tcp   private   S0          0          0     0
# 3              0           tcp      http   SF        232       8153     0
# 4              0           tcp      http   SF        199        420     0
# ...          ...           ...       ...  ...        ...        ...   ...
# 125968         0           tcp   private   S0          0          0     0
# 125969         8           udp   private   SF        105        145     0
# 125970         0           tcp      smtp   SF       2231        384     0
# 125971         0           tcp    klogin   S0          0          0     0
# 125972         0           tcp  ftp_data   SF        151          0     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0                    0       0    0  ...                    0.17
# 1                    0       0    0  ...                    0.00
# 2                    0       0    0  ...                    0.10
# 3                    0       0    0  ...                    1.00
# 4                    0       0    0  ...                    1.00
# ...                ...     ...  ...  ...                     ...
# 125968               0       0    0  ...                    0.10
# 125969               0       0    0  ...                    0.96
# 125970               0       0    0  ...                    0.12
# 125971               0       0    0  ...                    0.03
# 125972               0       0    0  ...                    0.30
#
#         dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                         0.03                         0.17
# 1                         0.60                         0.88
# 2                         0.05                         0.00
# 3                         0.00                         0.03
# 4                         0.00                         0.00
# ...                        ...                          ...
# 125968                    0.06                         0.00
# 125969                    0.01                         0.01
# 125970                    0.06                         0.00
# 125971                    0.05                         0.00
# 125972                    0.03                         0.30
#
#         dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                              0.00                  0.00
# 1                              0.00                  0.00
# 2                              0.00                  1.00
# 3                              0.04                  0.03
# 4                              0.00                  0.00
# ...                             ...                   ...
# 125968                         0.00                  1.00
# 125969                         0.00                  0.00
# 125970                         0.00                  0.72
# 125971                         0.00                  1.00
# 125972                         0.00                  0.00
#
#         dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                           0.00                  0.05
# 1                           0.00                  0.00
# 2                           1.00                  0.00
# 3                           0.01                  0.00
# 4                           0.00                  0.00
# ...                          ...                   ...
# 125968                      1.00                  0.00
# 125969                      0.00                  0.00
# 125970                      0.00                  0.01
# 125971                      1.00                  0.00
# 125972                      0.00                  0.00
#
#         dst_host_srv_rerror_rate    label  difficulty_level
# 0                           0.00   normal                20
# 1                           0.00   normal                15
# 2                           0.00  neptune                19
# 3                           0.01   normal                21
# 4                           0.00   normal                21
# ...                          ...      ...               ...
# 125968                      0.00  neptune                20
# 125969                      0.00   normal                21
# 125970                      0.00   normal                18
# 125971                      0.00  neptune                20
# 125972                      0.00   normal                21
#
# [125973 rows x 43 columns]

# %%
# remove attribute 'difficulty_level'
data.drop(['difficulty_level'],axis=1,inplace=True)
data.shape
# Out:
# (125973, 42)

# %%
# descriptive statistics of dataset
data.describe()
# Out:
#            duration     src_bytes     dst_bytes           land  \
# count  125973.00000  1.259730e+05  1.259730e+05  125973.000000
# mean      287.14465  4.556674e+04  1.977911e+04       0.000198
# std      2604.51531  5.870331e+06  4.021269e+06       0.014086
# min         0.00000  0.000000e+00  0.000000e+00       0.000000
# 25%         0.00000  0.000000e+00  0.000000e+00       0.000000
# 50%         0.00000  4.400000e+01  0.000000e+00       0.000000
# 75%         0.00000  2.760000e+02  5.160000e+02       0.000000
# max     42908.00000  1.379964e+09  1.309937e+09       1.000000
#
#        wrong_fragment         urgent            hot  num_failed_logins  \
# count   125973.000000  125973.000000  125973.000000      125973.000000
# mean         0.022687       0.000111       0.204409           0.001222
# std          0.253530       0.014366       2.149968           0.045239
# min          0.000000       0.000000       0.000000           0.000000
# 25%          0.000000       0.000000       0.000000           0.000000
# 50%          0.000000       0.000000       0.000000           0.000000
# 75%          0.000000       0.000000       0.000000           0.000000
# max          3.000000       3.000000      77.000000           5.000000
#
#            logged_in  num_compromised  ...  dst_host_count  \
# count  125973.000000    125973.000000  ...   125973.000000
# mean        0.395736         0.279250  ...      182.148945
# std         0.489010        23.942042  ...       99.206213
# min         0.000000         0.000000  ...        0.000000
# 25%         0.000000         0.000000  ...       82.000000
# 50%         0.000000         0.000000  ...      255.000000
# 75%         1.000000         0.000000  ...      255.000000
# max         1.000000      7479.000000  ...      255.000000
#
#        dst_host_srv_count  dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# count       125973.000000           125973.000000           125973.000000
# mean           115.653005                0.521242                0.082951
# std            110.702741                0.448949                0.188922
# min              0.000000                0.000000                0.000000
# 25%             10.000000                0.050000                0.000000
# 50%             63.000000                0.510000                0.020000
# 75%            255.000000                1.000000                0.070000
# max            255.000000                1.000000                1.000000
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# count                125973.000000                125973.000000
# mean                      0.148379                     0.032542
# std                       0.308997                     0.112564
# min                       0.000000                     0.000000
# 25%                       0.000000                     0.000000
# 50%                       0.000000                     0.000000
# 75%                       0.060000                     0.020000
# max                       1.000000                     1.000000
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# count         125973.000000             125973.000000         125973.000000
# mean               0.284452                  0.278485              0.118832
# std                0.444784                  0.445669              0.306557
# min                0.000000                  0.000000              0.000000
# 25%                0.000000                  0.000000              0.000000
# 50%                0.000000                  0.000000              0.000000
# 75%                1.000000                  1.000000              0.000000
# max                1.000000                  1.000000              1.000000
#
#        dst_host_srv_rerror_rate
# count             125973.000000
# mean                   0.120240
# std                    0.319459
# min                    0.000000
# 25%                    0.000000
# 50%                    0.000000
# 75%                    0.000000
# max                    1.000000
#
# [8 rows x 38 columns]

# %%
# number of attack labels
data['label'].value_counts()
# Out:
# label
# normal             67343
# neptune            41214
# satan               3633
# ipsweep             3599
# portsweep           2931
# smurf               2646
# nmap                1493
# back                 956
# teardrop             892
# warezclient          890
# pod                  201
# guess_passwd          53
# buffer_overflow       30
# warezmaster           20
# land                  18
# imap                  11
# rootkit               10
# loadmodule             9
# ftp_write              8
# multihop               7
# phf                    4
# perl                   3
# spy                    2
# Name: count, dtype: int64

# %%
# changing attack labels to their respective attack class
def change_label(df):
  df.label.replace(['apache2','back','land','neptune','mailbomb','pod','processtable','smurf','teardrop','udpstorm','worm'],'Dos',inplace=True)
  df.label.replace(['ftp_write','guess_passwd','httptunnel','imap','multihop','named','phf','sendmail',
       'snmpgetattack','snmpguess','spy','warezclient','warezmaster','xlock','xsnoop'],'R2L',inplace=True)
  df.label.replace(['ipsweep','mscan','nmap','portsweep','saint','satan'],'Probe',inplace=True)
  df.label.replace(['buffer_overflow','loadmodule','perl','ps','rootkit','sqlattack','xterm'],'U2R',inplace=True)

# %%
# calling change_label() function
change_label(data)

# %%
# distribution of attack classes
data.label.value_counts()
# Out:
# label
# normal    67343
# Dos       45927
# Probe     11656
# R2L         995
# U2R          52
# Name: count, dtype: int64

# %% [markdown]
# # **Data Normalization**

# %%
# selecting numeric attributes columns from data
numeric_col = data.select_dtypes(include='number').columns

# %%
# using standard scaler for normalizing
std_scaler = StandardScaler()
def normalization(df,col):
  for i in col:
    arr = df[i]
    arr = np.array(arr)
    df[i] = std_scaler.fit_transform(arr.reshape(len(arr),1))
  return df

# %%
# data before normalization
data.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# 3                    1.00                    0.00
# 4                    1.00                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# 1                         0.88                         0.00
# 2                         0.00                         0.00
# 3                         0.03                         0.04
# 4                         0.00                         0.00
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                  0.00                      0.00                  0.05
# 1                  0.00                      0.00                  0.00
# 2                  1.00                      1.00                  0.00
# 3                  0.03                      0.01                  0.00
# 4                  0.00                      0.00                  0.00
#
#    dst_host_srv_rerror_rate   label
# 0                      0.00  normal
# 1                      0.00  normal
# 2                      0.00     Dos
# 3                      0.01  normal
# 4                      0.00  normal
#
# [5 rows x 42 columns]

# %%
# calling the normalization() function
data = normalization(data.copy(),numeric_col)

# %%
# data after normalization
data.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes      land  \
# 0 -0.110249           tcp  ftp_data   SF  -0.007679  -0.004919 -0.014089
# 1 -0.110249           udp     other   SF  -0.007737  -0.004919 -0.014089
# 2 -0.110249           tcp   private   S0  -0.007762  -0.004919 -0.014089
# 3 -0.110249           tcp      http   SF  -0.007723  -0.002891 -0.014089
# 4 -0.110249           tcp      http   SF  -0.007728  -0.004814 -0.014089
#
#    wrong_fragment    urgent       hot  ...  dst_host_srv_count  \
# 0       -0.089486 -0.007736 -0.095076  ...           -0.818890
# 1       -0.089486 -0.007736 -0.095076  ...           -1.035688
# 2       -0.089486 -0.007736 -0.095076  ...           -0.809857
# 3       -0.089486 -0.007736 -0.095076  ...            1.258754
# 4       -0.089486 -0.007736 -0.095076  ...            1.258754
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0               -0.782367               -0.280282
# 1               -1.161030                2.736852
# 2               -0.938287               -0.174417
# 3                1.066401               -0.439078
# 4                1.066401               -0.439078
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                     0.069972                    -0.289103
# 1                     2.367737                    -0.289103
# 2                    -0.480197                    -0.289103
# 3                    -0.383108                     0.066252
# 4                    -0.480197                    -0.289103
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0             -0.639532                 -0.624871             -0.224532
# 1             -0.639532                 -0.624871             -0.387635
# 2              1.608759                  1.618955             -0.387635
# 3             -0.572083                 -0.602433             -0.387635
# 4             -0.639532                 -0.624871             -0.387635
#
#    dst_host_srv_rerror_rate   label
# 0                 -0.376387  normal
# 1                 -0.376387  normal
# 2                 -0.376387     Dos
# 3                 -0.345084  normal
# 4                 -0.376387  normal
#
# [5 rows x 42 columns]

# %% [markdown]
# # **One-hot-encoding**

# %%
# selecting categorical data attributes
cat_col = ['protocol_type','service','flag']

# %%
# creating a dataframe with only categorical attributes
categorical = data[cat_col]
categorical.head()
# Out:
#   protocol_type   service flag
# 0           tcp  ftp_data   SF
# 1           udp     other   SF
# 2           tcp   private   S0
# 3           tcp      http   SF
# 4           tcp      http   SF

# %%
# one-hot-encoding categorical attributes using pandas.get_dummies() function
categorical = pd.get_dummies(categorical,columns=cat_col)
categorical.head()
# Out:
#    protocol_type_icmp  protocol_type_tcp  protocol_type_udp  service_IRC  \
# 0               False               True              False        False
# 1               False              False               True        False
# 2               False               True              False        False
# 3               False               True              False        False
# 4               False               True              False        False
#
#    service_X11  service_Z39_50  service_aol  service_auth  service_bgp  \
# 0        False           False        False         False        False
# 1        False           False        False         False        False
# 2        False           False        False         False        False
# 3        False           False        False         False        False
# 4        False           False        False         False        False
#
#    service_courier  ...  flag_REJ  flag_RSTO  flag_RSTOS0  flag_RSTR  flag_S0  \
# 0            False  ...     False      False        False      False    False
# 1            False  ...     False      False        False      False    False
# 2            False  ...     False      False        False      False     True
# 3            False  ...     False      False        False      False    False
# 4            False  ...     False      False        False      False    False
#
#    flag_S1  flag_S2  flag_S3  flag_SF  flag_SH
# 0    False    False    False     True    False
# 1    False    False    False     True    False
# 2    False    False    False    False    False
# 3    False    False    False     True    False
# 4    False    False    False     True    False
#
# [5 rows x 84 columns]

# %% [markdown]
# # **Binary Classification**

# %%
# changing attack labels into two categories 'normal' and 'abnormal'
bin_label = pd.DataFrame(data.label.map(lambda x:'normal' if x=='normal' else 'abnormal'))

# %%
# creating a dataframe with binary labels (normal,abnormal)
bin_data = data.copy()
bin_data['label'] = bin_label

# %%
# label encoding (0,1) binary labels (abnormal,normal)
le1 = preprocessing.LabelEncoder()
enc_label = bin_label.apply(le1.fit_transform)
bin_data['intrusion'] = enc_label

# %%
np.save("labels/le1_classes.npy",le1.classes_,allow_pickle=True)

# %%
# dataset with binary labels and label encoded column
bin_data.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes      land  \
# 0 -0.110249           tcp  ftp_data   SF  -0.007679  -0.004919 -0.014089
# 1 -0.110249           udp     other   SF  -0.007737  -0.004919 -0.014089
# 2 -0.110249           tcp   private   S0  -0.007762  -0.004919 -0.014089
# 3 -0.110249           tcp      http   SF  -0.007723  -0.002891 -0.014089
# 4 -0.110249           tcp      http   SF  -0.007728  -0.004814 -0.014089
#
#    wrong_fragment    urgent       hot  ...  dst_host_same_srv_rate  \
# 0       -0.089486 -0.007736 -0.095076  ...               -0.782367
# 1       -0.089486 -0.007736 -0.095076  ...               -1.161030
# 2       -0.089486 -0.007736 -0.095076  ...               -0.938287
# 3       -0.089486 -0.007736 -0.095076  ...                1.066401
# 4       -0.089486 -0.007736 -0.095076  ...                1.066401
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0               -0.280282                     0.069972
# 1                2.736852                     2.367737
# 2               -0.174417                    -0.480197
# 3               -0.439078                    -0.383108
# 4               -0.439078                    -0.480197
#
#    dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                    -0.289103             -0.639532
# 1                    -0.289103             -0.639532
# 2                    -0.289103              1.608759
# 3                     0.066252             -0.572083
# 4                    -0.289103             -0.639532
#
#    dst_host_srv_serror_rate  dst_host_rerror_rate  dst_host_srv_rerror_rate  \
# 0                 -0.624871             -0.224532                 -0.376387
# 1                 -0.624871             -0.387635                 -0.376387
# 2                  1.618955             -0.387635                 -0.376387
# 3                 -0.602433             -0.387635                 -0.345084
# 4                 -0.624871             -0.387635                 -0.376387
#
#       label  intrusion
# 0    normal          1
# 1    normal          1
# 2  abnormal          0
# 3    normal          1
# 4    normal          1
#
# [5 rows x 43 columns]

# %%
# one-hot-encoding attack label
bin_data = pd.get_dummies(bin_data,columns=['label'],prefix="",prefix_sep="")
bin_data['label'] = bin_label
bin_data
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes      land  \
# 0      -0.110249           tcp  ftp_data   SF  -0.007679  -0.004919 -0.014089
# 1      -0.110249           udp     other   SF  -0.007737  -0.004919 -0.014089
# 2      -0.110249           tcp   private   S0  -0.007762  -0.004919 -0.014089
# 3      -0.110249           tcp      http   SF  -0.007723  -0.002891 -0.014089
# 4      -0.110249           tcp      http   SF  -0.007728  -0.004814 -0.014089
# ...          ...           ...       ...  ...        ...        ...       ...
# 125968 -0.110249           tcp   private   S0  -0.007762  -0.004919 -0.014089
# 125969 -0.107178           udp   private   SF  -0.007744  -0.004883 -0.014089
# 125970 -0.110249           tcp      smtp   SF  -0.007382  -0.004823 -0.014089
# 125971 -0.110249           tcp    klogin   S0  -0.007762  -0.004919 -0.014089
# 125972 -0.110249           tcp  ftp_data   SF  -0.007737  -0.004919 -0.014089
#
#         wrong_fragment    urgent       hot  ...  dst_host_same_src_port_rate  \
# 0            -0.089486 -0.007736 -0.095076  ...                     0.069972
# 1            -0.089486 -0.007736 -0.095076  ...                     2.367737
# 2            -0.089486 -0.007736 -0.095076  ...                    -0.480197
# 3            -0.089486 -0.007736 -0.095076  ...                    -0.383108
# 4            -0.089486 -0.007736 -0.095076  ...                    -0.480197
# ...                ...       ...       ...  ...                          ...
# 125968       -0.089486 -0.007736 -0.095076  ...                    -0.480197
# 125969       -0.089486 -0.007736 -0.095076  ...                    -0.447834
# 125970       -0.089486 -0.007736 -0.095076  ...                    -0.480197
# 125971       -0.089486 -0.007736 -0.095076  ...                    -0.480197
# 125972       -0.089486 -0.007736 -0.095076  ...                     0.490690
#
#         dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                         -0.289103             -0.639532
# 1                         -0.289103             -0.639532
# 2                         -0.289103              1.608759
# 3                          0.066252             -0.572083
# 4                         -0.289103             -0.639532
# ...                             ...                   ...
# 125968                    -0.289103              1.608759
# 125969                    -0.289103             -0.639532
# 125970                    -0.289103              0.979238
# 125971                    -0.289103              1.608759
# 125972                    -0.289103             -0.639532
#
#         dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                      -0.624871             -0.224532
# 1                      -0.624871             -0.387635
# 2                       1.618955             -0.387635
# 3                      -0.602433             -0.387635
# 4                      -0.624871             -0.387635
# ...                          ...                   ...
# 125968                  1.618955             -0.387635
# 125969                 -0.624871             -0.387635
# 125970                 -0.624871             -0.355014
# 125971                  1.618955             -0.387635
# 125972                 -0.624871             -0.387635
#
#         dst_host_srv_rerror_rate  intrusion  abnormal  normal     label
# 0                      -0.376387          1     False    True    normal
# 1                      -0.376387          1     False    True    normal
# 2                      -0.376387          0      True   False  abnormal
# 3                      -0.345084          1     False    True    normal
# 4                      -0.376387          1     False    True    normal
# ...                          ...        ...       ...     ...       ...
# 125968                 -0.376387          0      True   False  abnormal
# 125969                 -0.376387          1     False    True    normal
# 125970                 -0.376387          1     False    True    normal
# 125971                 -0.376387          0      True   False  abnormal
# 125972                 -0.376387          1     False    True    normal
#
# [125973 rows x 45 columns]

# %%
# pie chart distribution of normal and abnormal labels
plt.figure(figsize=(8,8))
plt.pie(bin_data.label.value_counts(),labels=bin_data.label.unique(),autopct='%0.2f%%')
plt.title("Pie chart distribution of normal and abnormal labels")
plt.legend()
plt.savefig('plots/Pie_chart_binary.png')
plt.show()

# %% [markdown]
# # **Multi-class Classification**

# %%
# creating a dataframe with multi-class labels (Dos,Probe,R2L,U2R,normal)
multi_data = data.copy()
multi_label = pd.DataFrame(multi_data.label)

# %%
# label encoding (0,1,2,3,4) multi-class labels (Dos,normal,Probe,R2L,U2R)
le2 = preprocessing.LabelEncoder()
enc_label = multi_label.apply(le2.fit_transform)
multi_data['intrusion'] = enc_label

# %%
np.save("labels/le2_classes.npy",le2.classes_,allow_pickle=True)

# %%
# one-hot-encoding attack label
multi_data = pd.get_dummies(multi_data,columns=['label'],prefix="",prefix_sep="")
multi_data['label'] = multi_label
multi_data
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes      land  \
# 0      -0.110249           tcp  ftp_data   SF  -0.007679  -0.004919 -0.014089
# 1      -0.110249           udp     other   SF  -0.007737  -0.004919 -0.014089
# 2      -0.110249           tcp   private   S0  -0.007762  -0.004919 -0.014089
# 3      -0.110249           tcp      http   SF  -0.007723  -0.002891 -0.014089
# 4      -0.110249           tcp      http   SF  -0.007728  -0.004814 -0.014089
# ...          ...           ...       ...  ...        ...        ...       ...
# 125968 -0.110249           tcp   private   S0  -0.007762  -0.004919 -0.014089
# 125969 -0.107178           udp   private   SF  -0.007744  -0.004883 -0.014089
# 125970 -0.110249           tcp      smtp   SF  -0.007382  -0.004823 -0.014089
# 125971 -0.110249           tcp    klogin   S0  -0.007762  -0.004919 -0.014089
# 125972 -0.110249           tcp  ftp_data   SF  -0.007737  -0.004919 -0.014089
#
#         wrong_fragment    urgent       hot  ...  dst_host_srv_serror_rate  \
# 0            -0.089486 -0.007736 -0.095076  ...                 -0.624871
# 1            -0.089486 -0.007736 -0.095076  ...                 -0.624871
# 2            -0.089486 -0.007736 -0.095076  ...                  1.618955
# 3            -0.089486 -0.007736 -0.095076  ...                 -0.602433
# 4            -0.089486 -0.007736 -0.095076  ...                 -0.624871
# ...                ...       ...       ...  ...                       ...
# 125968       -0.089486 -0.007736 -0.095076  ...                  1.618955
# 125969       -0.089486 -0.007736 -0.095076  ...                 -0.624871
# 125970       -0.089486 -0.007736 -0.095076  ...                 -0.624871
# 125971       -0.089486 -0.007736 -0.095076  ...                  1.618955
# 125972       -0.089486 -0.007736 -0.095076  ...                 -0.624871
#
#         dst_host_rerror_rate  dst_host_srv_rerror_rate  intrusion    Dos  \
# 0                  -0.224532                 -0.376387          4  False
# 1                  -0.387635                 -0.376387          4  False
# 2                  -0.387635                 -0.376387          0   True
# 3                  -0.387635                 -0.345084          4  False
# 4                  -0.387635                 -0.376387          4  False
# ...                      ...                       ...        ...    ...
# 125968             -0.387635                 -0.376387          0   True
# 125969             -0.387635                 -0.376387          4  False
# 125970             -0.355014                 -0.376387          4  False
# 125971             -0.387635                 -0.376387          0   True
# 125972             -0.387635                 -0.376387          4  False
#
#         Probe    R2L    U2R  normal   label
# 0       False  False  False    True  normal
# 1       False  False  False    True  normal
# 2       False  False  False   False     Dos
# 3       False  False  False    True  normal
# 4       False  False  False    True  normal
# ...       ...    ...    ...     ...     ...
# 125968  False  False  False   False     Dos
# 125969  False  False  False    True  normal
# 125970  False  False  False    True  normal
# 125971  False  False  False   False     Dos
# 125972  False  False  False    True  normal
#
# [125973 rows x 48 columns]

# %%
# pie chart distribution of multi-class labels
plt.figure(figsize=(8,8))
plt.pie(multi_data.label.value_counts(),labels=multi_data.label.unique(),autopct='%0.2f%%')
plt.title('Pie chart distribution of multi-class labels')
plt.legend()
plt.savefig('plots/Pie_chart_multi.png')
plt.show()

# %% [markdown]
# # **Feature Extraction**

# %%
# Creating a dataframe with only numeric attributes of binary class dataset and encoded label attribute
numeric_bin = bin_data[numeric_col].copy()  # Ensure a copy is made
numeric_bin.loc[:, 'intrusion'] = bin_data['intrusion'].values  # Use .loc to ensure assignment without warning

# %%
# finding the attributes which have more than 0.5 correlation with encoded attack label attribute
corr= numeric_bin.corr()
corr_y = abs(corr['intrusion'])
highest_corr = corr_y[corr_y >0.5]
highest_corr.sort_values(ascending=True)
# Out:
# count                       0.576444
# srv_serror_rate             0.648289
# serror_rate                 0.650652
# dst_host_serror_rate        0.651842
# dst_host_srv_serror_rate    0.654985
# logged_in                   0.690171
# dst_host_same_srv_rate      0.693803
# dst_host_srv_count          0.722535
# same_srv_rate               0.751913
# intrusion                   1.000000
# Name: intrusion, dtype: float64

# %%
# selecting attributes found by using pearson correlation coefficient
numeric_bin = bin_data[['count','srv_serror_rate','serror_rate','dst_host_serror_rate','dst_host_srv_serror_rate',
                         'logged_in','dst_host_same_srv_rate','dst_host_srv_count','same_srv_rate']]

# %%
# joining the selected attribute with the one-hot-encoded categorical dataframe
numeric_bin = numeric_bin.join(categorical)
# then joining encoded, one-hot-encoded, and original attack label attribute
bin_data = numeric_bin.join(bin_data[['intrusion','abnormal','normal','label']])

# %%
# saving final dataset to disk
bin_data.to_csv("./datasets/bin_data.csv")
# final dataset for binary classification
bin_data
# Out:
#            count  srv_serror_rate  serror_rate  dst_host_serror_rate  \
# 0      -0.717045        -0.631929    -0.637209             -0.639532
# 1      -0.620982        -0.631929    -0.637209             -0.639532
# 2       0.339648         1.605104     1.602664              1.608759
# 3      -0.690846        -0.184522    -0.189235             -0.572083
# 4      -0.472521        -0.631929    -0.637209             -0.639532
# ...          ...              ...          ...                   ...
# 125968  0.872361         1.605104     1.602664              1.608759
# 125969 -0.717045        -0.631929    -0.637209             -0.639532
# 125970 -0.725778        -0.631929    -0.637209              0.979238
# 125971  0.523041         1.605104     1.602664              1.608759
# 125972 -0.725778        -0.631929    -0.637209             -0.639532
#
#         dst_host_srv_serror_rate  logged_in  dst_host_same_srv_rate  \
# 0                      -0.624871  -0.809262               -0.782367
# 1                      -0.624871  -0.809262               -1.161030
# 2                       1.618955  -0.809262               -0.938287
# 3                      -0.602433   1.235694                1.066401
# 4                      -0.624871   1.235694                1.066401
# ...                          ...        ...                     ...
# 125968                  1.618955  -0.809262               -0.938287
# 125969                 -0.624871  -0.809262                0.977304
# 125970                 -0.624871   1.235694               -0.893738
# 125971                  1.618955  -0.809262               -1.094207
# 125972                 -0.624871   1.235694               -0.492801
#
#         dst_host_srv_count  same_srv_rate  protocol_type_icmp  ...  flag_S0  \
# 0                -0.818890       0.771283               False  ...    False
# 1                -1.035688      -1.321428               False  ...    False
# 2                -0.809857      -1.389669               False  ...     True
# 3                 1.258754       0.771283               False  ...    False
# 4                 1.258754       0.771283               False  ...    False
# ...                    ...            ...                 ...  ...      ...
# 125968           -0.818890      -1.184947               False  ...     True
# 125969            1.159389       0.771283               False  ...    False
# 125970           -0.773724       0.771283               False  ...    False
# 125971           -0.972455      -1.366922               False  ...     True
# 125972           -0.349162       0.771283               False  ...    False
#
#         flag_S1  flag_S2  flag_S3  flag_SF  flag_SH  intrusion  abnormal  \
# 0         False    False    False     True    False          1     False
# 1         False    False    False     True    False          1     False
# 2         False    False    False    False    False          0      True
# 3         False    False    False     True    False          1     False
# 4         False    False    False     True    False          1     False
# ...         ...      ...      ...      ...      ...        ...       ...
# 125968    False    False    False    False    False          0      True
# 125969    False    False    False     True    False          1     False
# 125970    False    False    False     True    False          1     False
# 125971    False    False    False    False    False          0      True
# 125972    False    False    False     True    False          1     False
#
#         normal     label
# 0         True    normal
# 1         True    normal
# 2        False  abnormal
# 3         True    normal
# 4         True    normal
# ...        ...       ...
# 125968   False  abnormal
# 125969    True    normal
# 125970    True    normal
# 125971   False  abnormal
# 125972    True    normal
#
# [125973 rows x 97 columns]

# %%
# Creating a dataframe with only numeric attributes of multi-class dataset and encoded label attribute
numeric_multi = multi_data[numeric_col].copy()  # Ensure a copy is made
numeric_multi.loc[:, 'intrusion'] = multi_data['intrusion'].values  # Use .loc to ensure assignment without warning

# %%
# finding the attributes which have more than 0.5 correlation with encoded attack label attribute
corr = numeric_multi.corr()
corr_y = abs(corr['intrusion'])
highest_corr = corr_y[corr_y >0.5]
highest_corr.sort_values(ascending=True)
# Out:
# count                       0.613251
# logged_in                   0.693770
# srv_serror_rate             0.710852
# serror_rate                 0.712861
# dst_host_serror_rate        0.714247
# dst_host_same_srv_rate      0.716820
# dst_host_srv_serror_rate    0.717387
# dst_host_srv_count          0.718579
# same_srv_rate               0.798358
# intrusion                   1.000000
# Name: intrusion, dtype: float64

# %%
# selecting attributes found by using pearson correlation coefficient
numeric_multi = multi_data[['count','logged_in','srv_serror_rate','serror_rate','dst_host_serror_rate',
                        'dst_host_same_srv_rate','dst_host_srv_serror_rate','dst_host_srv_count','same_srv_rate']]

# %%
# joining the selected attribute with the one-hot-encoded categorical dataframe
numeric_multi = numeric_multi.join(categorical)
# then joining encoded, one-hot-encoded, and original attack label attribute
multi_data = numeric_multi.join(multi_data[['intrusion','Dos','Probe','R2L','U2R','normal','label']])

# %%
# saving final dataset to disk
multi_data.to_csv('./datasets/multi_data.csv')

# final dataset for multi-class classification
multi_data
# Out:
#            count  logged_in  srv_serror_rate  serror_rate  \
# 0      -0.717045  -0.809262        -0.631929    -0.637209
# 1      -0.620982  -0.809262        -0.631929    -0.637209
# 2       0.339648  -0.809262         1.605104     1.602664
# 3      -0.690846   1.235694        -0.184522    -0.189235
# 4      -0.472521   1.235694        -0.631929    -0.637209
# ...          ...        ...              ...          ...
# 125968  0.872361  -0.809262         1.605104     1.602664
# 125969 -0.717045  -0.809262        -0.631929    -0.637209
# 125970 -0.725778   1.235694        -0.631929    -0.637209
# 125971  0.523041  -0.809262         1.605104     1.602664
# 125972 -0.725778   1.235694        -0.631929    -0.637209
#
#         dst_host_serror_rate  dst_host_same_srv_rate  \
# 0                  -0.639532               -0.782367
# 1                  -0.639532               -1.161030
# 2                   1.608759               -0.938287
# 3                  -0.572083                1.066401
# 4                  -0.639532                1.066401
# ...                      ...                     ...
# 125968              1.608759               -0.938287
# 125969             -0.639532                0.977304
# 125970              0.979238               -0.893738
# 125971              1.608759               -1.094207
# 125972             -0.639532               -0.492801
#
#         dst_host_srv_serror_rate  dst_host_srv_count  same_srv_rate  \
# 0                      -0.624871           -0.818890       0.771283
# 1                      -0.624871           -1.035688      -1.321428
# 2                       1.618955           -0.809857      -1.389669
# 3                      -0.602433            1.258754       0.771283
# 4                      -0.624871            1.258754       0.771283
# ...                          ...                 ...            ...
# 125968                  1.618955           -0.818890      -1.184947
# 125969                 -0.624871            1.159389       0.771283
# 125970                 -0.624871           -0.773724       0.771283
# 125971                  1.618955           -0.972455      -1.366922
# 125972                 -0.624871           -0.349162       0.771283
#
#         protocol_type_icmp  ...  flag_S3  flag_SF  flag_SH  intrusion    Dos  \
# 0                    False  ...    False     True    False          4  False
# 1                    False  ...    False     True    False          4  False
# 2                    False  ...    False    False    False          0   True
# 3                    False  ...    False     True    False          4  False
# 4                    False  ...    False     True    False          4  False
# ...                    ...  ...      ...      ...      ...        ...    ...
# 125968               False  ...    False    False    False          0   True
# 125969               False  ...    False     True    False          4  False
# 125970               False  ...    False     True    False          4  False
# 125971               False  ...    False    False    False          0   True
# 125972               False  ...    False     True    False          4  False
#
#         Probe    R2L    U2R  normal   label
# 0       False  False  False    True  normal
# 1       False  False  False    True  normal
# 2       False  False  False   False     Dos
# 3       False  False  False    True  normal
# 4       False  False  False    True  normal
# ...       ...    ...    ...     ...     ...
# 125968  False  False  False   False     Dos
# 125969  False  False  False    True  normal
# 125970  False  False  False    True  normal
# 125971  False  False  False   False     Dos
# 125972  False  False  False    True  normal
#
# [125973 rows x 100 columns]

# %% [markdown]
#  # ***Traditional Machine Learning Algorithms***

# %% [markdown]
# # **Linear Support Vector Machine Classifier (Binary Classification)**

# %%
X = bin_data.iloc[:,0:93].to_numpy() # dataset excluding target attribute (encoded, one-hot-encoded,original)
Y = bin_data['intrusion'] # target attribute

# %%
# splitting the dataset 75% for training and 25% testing
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.25, random_state=42)

# %%
# using kernel as linear
lsvm = SVC(kernel='linear',gamma='auto')
lsvm.fit(X,Y) # training model on training dataset
# Out:
# SVC(gamma='auto', kernel='linear')

# %%
pkl_filename = "./models/lsvm_binary.pkl"
if (not path.isfile(pkl_filename)):
  # saving the trained model to disk
  with open(pkl_filename, 'wb') as file:
    pickle.dump(lsvm, file)
  print("Saved model to disk")
  # loading the trained model from disk
  with open(pkl_filename, 'rb') as file:
    lsvm = pickle.load(file)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
y_pred = lsvm.predict(X_test) # predicting target attribute on testing dataset
ac = accuracy_score(y_test, y_pred)*100 # calculating accuracy of predicted data
print("LSVM-Classifier Binary Set-Accuracy is ", ac)
# Out:
# LSVM-Classifier Binary Set-Accuracy is  96.69460849685655

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le1.classes_))
# Out:
#               precision    recall  f1-score   support
#
#     abnormal       0.97      0.96      0.96     14720
#       normal       0.96      0.97      0.97     16774
#
#     accuracy                           0.97     31494
#    macro avg       0.97      0.97      0.97     31494
# weighted avg       0.97      0.97      0.97     31494

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)
# Out:
# Mean Absolute Error -  0.03305391503143456
# Mean Squared Error -  0.03305391503143456
# Root Mean Squared Error -  0.1818073569232955
# R2 Score -  86.73245400166407
# Accuracy -  96.69460849685655

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[300:500], label="prediction", linewidth=2.0,color='blue')
plt.plot(y_test[300:500].values, label="real_values", linewidth=2.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,2))
plt.title("Linear SVM Binary Classification")
plt.savefig('plots/lsvm_real_pred_bin.png')
plt.show()

# %% [markdown]
# # **Quadratic Support Vector Machine Classifier (Binary Classification)**

# %%
qsvm=SVC(kernel='poly',gamma='auto') # using kernal as polynomial for quadratic svm
qsvm.fit(X,Y) # training model on training dataset
# Out:
# SVC(gamma='auto', kernel='poly')

# %%
pkl_filename = "./models/qsvm_binary.pkl"
if (not path.isfile(pkl_filename)):
  # saving the trained model to disk
  with open(pkl_filename, 'wb') as file:
    pickle.dump(qsvm, file)
  print("Saved model to disk")
  # loading the trained model from disk
  with open(pkl_filename, 'rb') as file:
    qsvm = pickle.load(file)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
y_pred=qsvm.predict(X_test) # predicting target attribute on testing dataset
ac=accuracy_score(y_test, y_pred)*100 # calculating accuracy of predicted data
print("QSVM-Classifier Binary Set-Accuracy is ", ac)
# Out:
# QSVM-Classifier Binary Set-Accuracy is  95.86270400711247

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le1.classes_))
# Out:
#               precision    recall  f1-score   support
#
#     abnormal       0.99      0.92      0.95     14720
#       normal       0.94      0.99      0.96     16774
#
#     accuracy                           0.96     31494
#    macro avg       0.96      0.96      0.96     31494
# weighted avg       0.96      0.96      0.96     31494

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)
# Out:
# Mean Absolute Error -  0.04137295992887534
# Mean Squared Error -  0.04137295992887534
# Root Mean Squared Error -  0.20340344129064125
# R2 Score -  83.78918420264799
# Accuracy -  95.86270400711247

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[400:600], label="prediction", linewidth=2.0,color='blue')
plt.plot(y_test[400:600].values, label="real_values", linewidth=2.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,2))
plt.title("Quadratic SVM Binary Classification")
plt.savefig('plots/qsvm_real_pred_bin.png')
plt.show()

# %% [markdown]
# # **K-nearest-neighbor Classifier (Binary Classification)**

# %%
knn=KNeighborsClassifier(n_neighbors=5) # creating model for 5 neighbors
knn.fit(X_train,y_train) # training model on training dataset
# Out:
# KNeighborsClassifier()

# %%
pkl_filename = "./models/knn_binary.pkl"
if (not path.isfile(pkl_filename)):
  # saving the trained model to disk
  with open(pkl_filename, 'wb') as file:
    pickle.dump(knn, file)
  print("Saved model to disk")
  # loading the trained model from disk
  with open(pkl_filename, 'rb') as file:
    knn = pickle.load(file)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
y_pred=knn.predict(X_test) # predicting target attribute on testing dataset
ac=accuracy_score(y_test, y_pred)*100 # calculating accuracy of predicted data
print("KNN-Classifier Binary Set-Accuracy is ", ac)
# Out:
# KNN-Classifier Binary Set-Accuracy is  98.57750682669715

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le1.classes_))
# Out:
#               precision    recall  f1-score   support
#
#     abnormal       0.99      0.98      0.98     14720
#       normal       0.99      0.99      0.99     16774
#
#     accuracy                           0.99     31494
#    macro avg       0.99      0.99      0.99     31494
# weighted avg       0.99      0.99      0.99     31494

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)
# Out:
# Mean Absolute Error -  0.014224931733028513
# Mean Squared Error -  0.014224931733028513
# Root Mean Squared Error -  0.11926831822839003
# R2 Score -  94.28595497172124
# Accuracy -  98.57750682669715

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[500:600], label="prediction", linewidth=2.0,color='blue')
plt.plot(y_test[500:600].values, label="real_values", linewidth=2.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,2))
plt.title("KNN Binary Classification")
plt.savefig('plots/knn_real_pred_bin.png')
plt.show()

# %% [markdown]
# # **Random Forest Classifier (Binary Classification)**

# %%
# Initialize the Random Forest classifier
rf = RandomForestClassifier(n_estimators=100, random_state=42)
# Train the model on training dataset
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Save the trained model to disk
pkl_filename = "./models/rf_binary.pkl"
if not path.isfile(pkl_filename):
    with open(pkl_filename, 'wb') as file:
        pickle.dump(rf, file)
    print("Saved model to disk")

# Load the trained model from disk
with open(pkl_filename, 'rb') as file:
    rf = pickle.load(file)
print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
# Predicting target attribute on testing dataset
y_pred = rf.predict(X_test)

# Calculating accuracy of predicted data
ac = accuracy_score(y_test, y_pred) * 100
print("Random Forest Classifier Binary Set - Accuracy is ", ac)
# Out:
# Random Forest Classifier Binary Set - Accuracy is  98.72356639359879

# %%
# Classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99     14720
#            1       0.99      0.99      0.99     16774
#
#     accuracy                           0.99     31494
#    macro avg       0.99      0.99      0.99     31494
# weighted avg       0.99      0.99      0.99     31494

# %%
print("Mean Absolute Error - ", metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - ", metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - ", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - ", metrics.explained_variance_score(y_test, y_pred) * 100)
print("Accuracy - ", accuracy_score(y_test, y_pred) * 100)
# Out:
# Mean Absolute Error -  0.012764336064012193
# Mean Squared Error -  0.012764336064012193
# Root Mean Squared Error -  0.11297936123032469
# R2 Score -  94.87381804656275
# Accuracy -  98.72356639359879

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[300:500], label="prediction", linewidth=2.0, color='blue')
plt.plot(y_test[300:500].values, label="real_values", linewidth=2.0, color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1, 2))
plt.title("Random Forest Binary Classification")
plt.savefig('plots/rf_real_pred_bin.png')
plt.show()

# %% [markdown]
# # **Linear Support Vector Machine Classifier (Multi-class Classification)**

# %%
X = multi_data.iloc[:,0:93].to_numpy() # dataset excluding target attribute (encoded, one-hot-encoded, original)
Y = multi_data['intrusion'] # target attribute

# %%
# splitting the dataset 75% for training and 25% testing
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.25, random_state=42)

# %%
lsvm=SVC(kernel='linear',gamma='auto')
lsvm.fit(X_train,y_train) # training model on training dataset
# Out:
# SVC(gamma='auto', kernel='linear')

# %%
# saving trained model to disk
pkl_filename = "./models/lsvm_multi.pkl"
if (not path.isfile(pkl_filename)):
  with open(pkl_filename, 'wb') as file:
    pickle.dump(lsvm, file)
  print("Saved model to disk")
  # loading trained model from disk
  with open(pkl_filename, 'rb') as file:
    lsvm = pickle.load(file)
  print("Loade model from disk")
# Out:
# Saved model to disk
# Loade model from disk

# %%
y_pred=lsvm.predict(X_test) # predicting target attribute on testing dataset
ac=accuracy_score(y_test, y_pred)*100  # calculating accuracy of predicted data
print("LSVM-Classifier Multi-class Set-Accuracy is ", ac)
# Out:
# LSVM-Classifier Multi-class Set-Accuracy is  95.24988886772083

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le2.classes_))
# Out:
#               precision    recall  f1-score   support
#
#          Dos       0.95      0.96      0.96     11484
#        Probe       0.86      0.79      0.82      2947
#          R2L       0.61      0.60      0.61       274
#          U2R       0.00      0.00      0.00        15
#       normal       0.97      0.98      0.98     16774
#
#     accuracy                           0.95     31494
#    macro avg       0.68      0.67      0.67     31494
# weighted avg       0.95      0.95      0.95     31494
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)
# Out:
# Mean Absolute Error -  0.10125738235854448
# Mean Squared Error -  0.2831967993903601
# Root Mean Squared Error -  0.5321623806606026
# R2 Score -  92.1868366533396
# Accuracy -  95.24988886772083

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[300:400], label="prediction", linewidth=2.0,color='blue')
plt.plot(y_test[300:400].values, label="real_values", linewidth=2.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,5))
plt.title("Linear SVM Multi-class Classification")
plt.savefig('plots/lsvm_real_pred_multi.png')
plt.show()

# %% [markdown]
# # **Quadratic Support Vector Machine Classifier (Multi-class Classification)**

# %%
qsvm=SVC(kernel='poly',gamma='auto')
qsvm.fit(X_train,y_train) # training model on training dataset
# Out:
# SVC(gamma='auto', kernel='poly')

# %%
pkl_filename = "./models/qsvm_multi.pkl"
if (not path.isfile(pkl_filename)):
  # saving trained model to disk
  with open(pkl_filename, 'wb') as file:
    pickle.dump(qsvm, file)
  print("Saved model to disk")
  # loading trained model from disk
  with open(pkl_filename, 'rb') as file:
    qsvm = pickle.load(file)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
y_pred=qsvm.predict(X_test)  # predicting target attribute on testing dataset
ac=accuracy_score(y_test, y_pred)*100  # calculating accuracy of predicted data
print("QSVM-Classifier Multi-class Set-Accuracy is ", ac)
# Out:
# QSVM-Classifier Multi-class Set-Accuracy is  92.86213246967677

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le2.classes_))
# Out:
#               precision    recall  f1-score   support
#
#          Dos       0.96      0.94      0.95     11484
#        Probe       0.96      0.61      0.74      2947
#          R2L       0.00      0.00      0.00       274
#          U2R       0.00      0.00      0.00        15
#       normal       0.91      1.00      0.95     16774
#
#     accuracy                           0.93     31494
#    macro avg       0.56      0.51      0.53     31494
# weighted avg       0.92      0.93      0.92     31494
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)
# Out:
# Mean Absolute Error -  0.1998158379373849
# Mean Squared Error -  0.6449164920302279
# Root Mean Squared Error -  0.8030669287364709
# R2 Score -  82.88055324849559
# Accuracy -  92.86213246967677

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[400:600], label="prediction", linewidth=1.0,color='blue')
plt.plot(y_test[400:600].values, label="real_values", linewidth=1.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,5))
plt.title("Quadratic SVM Multi-class Classification")
plt.savefig('plots/qsvm_real_pred_multi.png')
plt.show()

# %% [markdown]
# # **K-nearest-neighbor Classifier (Multi-class Classification)**

# %%
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,y_train) # training model on training dataset
# Out:
# KNeighborsClassifier()

# %%
pkl_filename = "./models/knn_multi.pkl"
if (not path.isfile(pkl_filename)):
  # saving trained model to disk
  with open(pkl_filename, 'wb') as file:
    pickle.dump(knn, file)
  print("Saved model to disk")
  # loading trained model from disk
  with open(pkl_filename, 'rb') as file:
    knn = pickle.load(file)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
y_pred=knn.predict(X_test)  # predicting target attribute on testing dataset
ac=accuracy_score(y_test, y_pred)*100  # calculating accuracy of predicted data
print("KNN-Classifier Multi-class Set-Accuracy is ", ac)
# Out:
# KNN-Classifier Multi-class Set-Accuracy is  98.29491331682225

# %%
# classification report
print(classification_report(y_test, y_pred,target_names=le2.classes_))
# Out:
#               precision    recall  f1-score   support
#
#          Dos       0.99      0.99      0.99     11484
#        Probe       0.96      0.96      0.96      2947
#          R2L       0.89      0.87      0.88       274
#          U2R       0.40      0.13      0.20        15
#       normal       0.99      0.99      0.99     16774
#
#     accuracy                           0.98     31494
#    macro avg       0.84      0.79      0.80     31494
# weighted avg       0.98      0.98      0.98     31494

# %%
print("Mean Absolute Error - " , metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - " , metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - " , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - " , metrics.explained_variance_score(y_test, y_pred)*100)
print("Accuracy - ",accuracy_score(y_test,y_pred)*100)
# Out:
# Mean Absolute Error -  0.050263542262018165
# Mean Squared Error -  0.16939734552613195
# Root Mean Squared Error -  0.411579087814398
# R2 Score -  95.32594781621742
# Accuracy -  98.29491331682225

# %%
plt.figure(figsize=(20,8))
plt.plot(y_pred[500:600], label="prediction", linewidth=2.0,color='blue')
plt.plot(y_test[500:600].values, label="real_values", linewidth=2.0,color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1,5))
plt.title("KNN Multi Classification")
plt.savefig('plots/knn_real_pred_multi.png')
plt.show()

# %% [markdown]
# # **Random Forest Classifier (Multi-class Classification)**

# %%
# Initialize the Random Forest classifier
rf = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model on training dataset
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Save the trained model to disk
pkl_filename = "./models/rf_multi.pkl"
if not path.isfile(pkl_filename):
    with open(pkl_filename, 'wb') as file:
        pickle.dump(rf, file)
    print("Saved model to disk")

# Load the trained model from disk
with open(pkl_filename, 'rb') as file:
    rf = pickle.load(file)
print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
# Predicting target attribute on testing dataset
y_pred = rf.predict(X_test)

# Calculating accuracy of predicted data
ac = accuracy_score(y_test, y_pred) * 100
print("Random Forest Classifier Multi-class Set - Accuracy is ", ac)
# Out:
# Random Forest Classifier Multi-class Set - Accuracy is  98.53622912300756

# %%
# Classification report
print(classification_report(y_test, y_pred, target_names=le2.classes_))
# Out:
#               precision    recall  f1-score   support
#
#          Dos       0.99      0.99      0.99     11484
#        Probe       0.97      0.97      0.97      2947
#          R2L       0.92      0.87      0.89       274
#          U2R       0.29      0.13      0.18        15
#       normal       0.99      0.99      0.99     16774
#
#     accuracy                           0.99     31494
#    macro avg       0.83      0.79      0.80     31494
# weighted avg       0.99      0.99      0.99     31494

# %%
print("Mean Absolute Error - ", metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error - ", metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error - ", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2 Score - ", metrics.explained_variance_score(y_test, y_pred) * 100)
print("Accuracy - ", accuracy_score(y_test, y_pred) * 100)
# Out:
# Mean Absolute Error -  0.044294151266907986
# Mean Squared Error -  0.1517431891788912
# Root Mean Squared Error -  0.3895422816317777
# R2 Score -  95.81432613448169
# Accuracy -  98.53622912300756

# %%
plt.figure(figsize=(20, 8))
plt.plot(y_pred[300:400], label="prediction", linewidth=2.0, color='blue')
plt.plot(y_test[300:400].values, label="real_values", linewidth=2.0, color='lightcoral')
plt.legend(loc="best")
plt.ylim((-1, 5))
plt.title("Random Forest Multi-class Classification")
plt.savefig('plots/rf_real_pred_multi.png')
plt.show()

# %% [markdown]
# #***Machine Learning-Based Neural Networks***

# %% [markdown]
# # **Long Short-Term Memory Classifier (Binary Classification)**

# %%
X = bin_data.iloc[:,0:93] # dataset excluding target attribute (encoded, one-hot-encoded,original)
Y = bin_data[['intrusion']] # target attribute

# %%
# splitting the dataset 75% for training and 25% testing
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.25, random_state=42)

# %%
X_train = X_train.values

# %%
y_train = np.array(y_train)

# %%
x_train = np.reshape(X_train, (X_train.shape[0],1,X_train.shape[1]))

# %%
x_train.shape
# Out:
# (94479, 1, 93)

# %%
lst = Sequential()
# input layer and LSTM layer with 50 neurons
lst.add(LSTM(50,input_dim=93))

# outpute layer with sigmoid activation
lst.add(Dense(1,activation='sigmoid'))

# %%
# defining loss function, optimizer, metrics and then compiling model
lst.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
# summary of model layers
lst.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50)                28800
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 28851 (112.70 KB)
# Trainable params: 28851 (112.70 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# training the model on training dataset
x_train = x_train.astype('float32')
y_train = y_train.astype('float32')

history = lst.fit(x_train, y_train, epochs=100, batch_size=5000,validation_split=0.2)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 5s 77ms/step - loss: 0.6332 - accuracy: 0.8105 - val_loss: 0.5535 - val_accuracy: 0.8906
# Epoch 2/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.4999 - accuracy: 0.8954 - val_loss: 0.4375 - val_accuracy: 0.9073
# Epoch 3/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.3974 - accuracy: 0.9095 - val_loss: 0.3514 - val_accuracy: 0.9146
# Epoch 4/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.3232 - accuracy: 0.9122 - val_loss: 0.2912 - val_accuracy: 0.9166
# Epoch 5/100
# 16/16 [==============================] - 1s 39ms/step - loss: 0.2717 - accuracy: 0.9143 - val_loss: 0.2496 - val_accuracy: 0.9184
# Epoch 6/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2355 - accuracy: 0.9168 - val_loss: 0.2198 - val_accuracy: 0.9210
# Epoch 7/100
# 16/16 [==============================] - 1s 37ms/step - loss: 0.2090 - accuracy: 0.9243 - val_loss: 0.1976 - val_accuracy: 0.9374
# Epoch 8/100
# 16/16 [==============================] - 1s 38ms/step - loss: 0.1888 - accuracy: 0.9409 - val_loss: 0.1804 - val_accuracy: 0.9476
# Epoch 9/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1728 - accuracy: 0.9492 - val_loss: 0.1667 - val_accuracy: 0.9527
# Epoch 10/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1600 - accuracy: 0.9543 - val_loss: 0.1556 - val_accuracy: 0.9566
# Epoch 11/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1495 - accuracy: 0.9590 - val_loss: 0.1465 - val_accuracy: 0.9602
# Epoch 12/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1410 - accuracy: 0.9620 - val_loss: 0.1391 - val_accuracy: 0.9622
# Epoch 13/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1339 - accuracy: 0.9636 - val_loss: 0.1329 - val_accuracy: 0.9639
# Epoch 14/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1281 - accuracy: 0.9656 - val_loss: 0.1278 - val_accuracy: 0.9661
# Epoch 15/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1233 - accuracy: 0.9671 - val_loss: 0.1235 - val_accuracy: 0.9670
# Epoch 16/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1192 - accuracy: 0.9679 - val_loss: 0.1196 - val_accuracy: 0.9678
# Epoch 17/100
# 16/16 [==============================] - 1s 34ms/step - loss: 0.1156 - accuracy: 0.9689 - val_loss: 0.1163 - val_accuracy: 0.9689
# Epoch 18/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.1123 - accuracy: 0.9696 - val_loss: 0.1132 - val_accuracy: 0.9696
# Epoch 19/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.1095 - accuracy: 0.9698 - val_loss: 0.1105 - val_accuracy: 0.9698
# Epoch 20/100
# 16/16 [==============================] - 1s 56ms/step - loss: 0.1068 - accuracy: 0.9699 - val_loss: 0.1079 - val_accuracy: 0.9698
# Epoch 21/100
# 16/16 [==============================] - 1s 58ms/step - loss: 0.1044 - accuracy: 0.9699 - val_loss: 0.1056 - val_accuracy: 0.9697
# Epoch 22/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.1022 - accuracy: 0.9701 - val_loss: 0.1035 - val_accuracy: 0.9698
# Epoch 23/100
# 16/16 [==============================] - 1s 58ms/step - loss: 0.1002 - accuracy: 0.9703 - val_loss: 0.1014 - val_accuracy: 0.9701
# Epoch 24/100
# 16/16 [==============================] - 1s 31ms/step - loss: 0.0982 - accuracy: 0.9705 - val_loss: 0.0995 - val_accuracy: 0.9704
# Epoch 25/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0964 - accuracy: 0.9709 - val_loss: 0.0978 - val_accuracy: 0.9705
# Epoch 26/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0948 - accuracy: 0.9710 - val_loss: 0.0961 - val_accuracy: 0.9708
# Epoch 27/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0932 - accuracy: 0.9711 - val_loss: 0.0945 - val_accuracy: 0.9708
# Epoch 28/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0917 - accuracy: 0.9712 - val_loss: 0.0930 - val_accuracy: 0.9707
# Epoch 29/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0903 - accuracy: 0.9713 - val_loss: 0.0917 - val_accuracy: 0.9708
# Epoch 30/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0890 - accuracy: 0.9715 - val_loss: 0.0904 - val_accuracy: 0.9709
# Epoch 31/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0878 - accuracy: 0.9717 - val_loss: 0.0892 - val_accuracy: 0.9708
# Epoch 32/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0866 - accuracy: 0.9718 - val_loss: 0.0881 - val_accuracy: 0.9708
# Epoch 33/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0856 - accuracy: 0.9717 - val_loss: 0.0869 - val_accuracy: 0.9708
# Epoch 34/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0845 - accuracy: 0.9718 - val_loss: 0.0859 - val_accuracy: 0.9705
# Epoch 35/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0835 - accuracy: 0.9717 - val_loss: 0.0849 - val_accuracy: 0.9704
# Epoch 36/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0826 - accuracy: 0.9718 - val_loss: 0.0841 - val_accuracy: 0.9704
# Epoch 37/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0818 - accuracy: 0.9719 - val_loss: 0.0832 - val_accuracy: 0.9705
# Epoch 38/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0809 - accuracy: 0.9720 - val_loss: 0.0824 - val_accuracy: 0.9706
# Epoch 39/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0801 - accuracy: 0.9720 - val_loss: 0.0816 - val_accuracy: 0.9706
# Epoch 40/100
# 16/16 [==============================] - 1s 31ms/step - loss: 0.0794 - accuracy: 0.9721 - val_loss: 0.0808 - val_accuracy: 0.9706
# Epoch 41/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0786 - accuracy: 0.9721 - val_loss: 0.0801 - val_accuracy: 0.9707
# Epoch 42/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0780 - accuracy: 0.9721 - val_loss: 0.0794 - val_accuracy: 0.9706
# Epoch 43/100
# 16/16 [==============================] - 1s 48ms/step - loss: 0.0773 - accuracy: 0.9721 - val_loss: 0.0787 - val_accuracy: 0.9709
# Epoch 44/100
# 16/16 [==============================] - 1s 51ms/step - loss: 0.0766 - accuracy: 0.9723 - val_loss: 0.0781 - val_accuracy: 0.9710
# Epoch 45/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0761 - accuracy: 0.9724 - val_loss: 0.0775 - val_accuracy: 0.9710
# Epoch 46/100
# 16/16 [==============================] - 1s 51ms/step - loss: 0.0755 - accuracy: 0.9724 - val_loss: 0.0770 - val_accuracy: 0.9712
# Epoch 47/100
# 16/16 [==============================] - 1s 58ms/step - loss: 0.0749 - accuracy: 0.9725 - val_loss: 0.0765 - val_accuracy: 0.9715
# Epoch 48/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0744 - accuracy: 0.9730 - val_loss: 0.0759 - val_accuracy: 0.9716
# Epoch 49/100
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0739 - accuracy: 0.9732 - val_loss: 0.0755 - val_accuracy: 0.9719
# Epoch 50/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0734 - accuracy: 0.9733 - val_loss: 0.0750 - val_accuracy: 0.9724
# Epoch 51/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0730 - accuracy: 0.9737 - val_loss: 0.0746 - val_accuracy: 0.9726
# Epoch 52/100
# 16/16 [==============================] - 1s 31ms/step - loss: 0.0726 - accuracy: 0.9743 - val_loss: 0.0742 - val_accuracy: 0.9735
# Epoch 53/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0722 - accuracy: 0.9749 - val_loss: 0.0739 - val_accuracy: 0.9737
# Epoch 54/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0719 - accuracy: 0.9757 - val_loss: 0.0735 - val_accuracy: 0.9743
# Epoch 55/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0714 - accuracy: 0.9756 - val_loss: 0.0732 - val_accuracy: 0.9744
# Epoch 56/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0711 - accuracy: 0.9765 - val_loss: 0.0728 - val_accuracy: 0.9753
# Epoch 57/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0708 - accuracy: 0.9765 - val_loss: 0.0726 - val_accuracy: 0.9749
# Epoch 58/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0705 - accuracy: 0.9770 - val_loss: 0.0723 - val_accuracy: 0.9755
# Epoch 59/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0702 - accuracy: 0.9773 - val_loss: 0.0720 - val_accuracy: 0.9756
# Epoch 60/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0699 - accuracy: 0.9773 - val_loss: 0.0718 - val_accuracy: 0.9756
# Epoch 61/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0697 - accuracy: 0.9771 - val_loss: 0.0716 - val_accuracy: 0.9755
# Epoch 62/100
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0694 - accuracy: 0.9774 - val_loss: 0.0713 - val_accuracy: 0.9757
# Epoch 63/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0691 - accuracy: 0.9772 - val_loss: 0.0710 - val_accuracy: 0.9758
# Epoch 64/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0689 - accuracy: 0.9773 - val_loss: 0.0709 - val_accuracy: 0.9759
# Epoch 65/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0687 - accuracy: 0.9773 - val_loss: 0.0707 - val_accuracy: 0.9759
# Epoch 66/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0684 - accuracy: 0.9773 - val_loss: 0.0704 - val_accuracy: 0.9759
# Epoch 67/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0683 - accuracy: 0.9775 - val_loss: 0.0703 - val_accuracy: 0.9760
# Epoch 68/100
# 16/16 [==============================] - 1s 43ms/step - loss: 0.0681 - accuracy: 0.9773 - val_loss: 0.0700 - val_accuracy: 0.9760
# Epoch 69/100
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0678 - accuracy: 0.9774 - val_loss: 0.0699 - val_accuracy: 0.9760
# Epoch 70/100
# 16/16 [==============================] - 1s 55ms/step - loss: 0.0677 - accuracy: 0.9774 - val_loss: 0.0697 - val_accuracy: 0.9759
# Epoch 71/100
# 16/16 [==============================] - 1s 50ms/step - loss: 0.0675 - accuracy: 0.9775 - val_loss: 0.0696 - val_accuracy: 0.9758
# Epoch 72/100
# 16/16 [==============================] - 1s 55ms/step - loss: 0.0673 - accuracy: 0.9775 - val_loss: 0.0694 - val_accuracy: 0.9757
# Epoch 73/100
# 16/16 [==============================] - 1s 55ms/step - loss: 0.0671 - accuracy: 0.9775 - val_loss: 0.0692 - val_accuracy: 0.9758
# Epoch 74/100
# 16/16 [==============================] - 1s 60ms/step - loss: 0.0669 - accuracy: 0.9775 - val_loss: 0.0690 - val_accuracy: 0.9760
# Epoch 75/100
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0668 - accuracy: 0.9777 - val_loss: 0.0689 - val_accuracy: 0.9761
# Epoch 76/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0666 - accuracy: 0.9777 - val_loss: 0.0687 - val_accuracy: 0.9761
# Epoch 77/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0664 - accuracy: 0.9777 - val_loss: 0.0685 - val_accuracy: 0.9761
# Epoch 78/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0663 - accuracy: 0.9777 - val_loss: 0.0685 - val_accuracy: 0.9762
# Epoch 79/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0661 - accuracy: 0.9778 - val_loss: 0.0683 - val_accuracy: 0.9761
# Epoch 80/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0660 - accuracy: 0.9778 - val_loss: 0.0682 - val_accuracy: 0.9760
# Epoch 81/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0658 - accuracy: 0.9780 - val_loss: 0.0681 - val_accuracy: 0.9762
# Epoch 82/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0657 - accuracy: 0.9779 - val_loss: 0.0679 - val_accuracy: 0.9758
# Epoch 83/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0656 - accuracy: 0.9779 - val_loss: 0.0677 - val_accuracy: 0.9759
# Epoch 84/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0654 - accuracy: 0.9779 - val_loss: 0.0677 - val_accuracy: 0.9760
# Epoch 85/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0653 - accuracy: 0.9781 - val_loss: 0.0676 - val_accuracy: 0.9762
# Epoch 86/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0651 - accuracy: 0.9780 - val_loss: 0.0674 - val_accuracy: 0.9759
# Epoch 87/100
# 16/16 [==============================] - 1s 31ms/step - loss: 0.0650 - accuracy: 0.9780 - val_loss: 0.0673 - val_accuracy: 0.9760
# Epoch 88/100
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0649 - accuracy: 0.9781 - val_loss: 0.0672 - val_accuracy: 0.9760
# Epoch 89/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0648 - accuracy: 0.9782 - val_loss: 0.0671 - val_accuracy: 0.9762
# Epoch 90/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0646 - accuracy: 0.9782 - val_loss: 0.0669 - val_accuracy: 0.9763
# Epoch 91/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0645 - accuracy: 0.9783 - val_loss: 0.0668 - val_accuracy: 0.9762
# Epoch 92/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0644 - accuracy: 0.9784 - val_loss: 0.0668 - val_accuracy: 0.9762
# Epoch 93/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0642 - accuracy: 0.9782 - val_loss: 0.0666 - val_accuracy: 0.9763
# Epoch 94/100
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0642 - accuracy: 0.9784 - val_loss: 0.0665 - val_accuracy: 0.9763
# Epoch 95/100
# 16/16 [==============================] - 1s 56ms/step - loss: 0.0640 - accuracy: 0.9782 - val_loss: 0.0664 - val_accuracy: 0.9763
# Epoch 96/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0639 - accuracy: 0.9784 - val_loss: 0.0662 - val_accuracy: 0.9763
# Epoch 97/100
# 16/16 [==============================] - 1s 56ms/step - loss: 0.0637 - accuracy: 0.9784 - val_loss: 0.0661 - val_accuracy: 0.9765
# Epoch 98/100
# 16/16 [==============================] - 1s 55ms/step - loss: 0.0636 - accuracy: 0.9784 - val_loss: 0.0660 - val_accuracy: 0.9765
# Epoch 99/100
# 16/16 [==============================] - 1s 56ms/step - loss: 0.0635 - accuracy: 0.9784 - val_loss: 0.0658 - val_accuracy: 0.9765
# Epoch 100/100
# 16/16 [==============================] - 1s 49ms/step - loss: 0.0634 - accuracy: 0.9784 - val_loss: 0.0658 - val_accuracy: 0.9765

# %%
X_test = X_test.to_numpy()

# %%
x_test = np.reshape(X_test, (X_test.shape[0],1,X_test.shape[1]))

# %%
filepath = './models/lst_binary.json'
weightspath = './weights/lst_binary.h5'
if (not path.isfile(filepath)):
  # serialize model to JSON
  lst_json = lst.to_json()
  with open(filepath, "w") as json_file:
    json_file.write(lst_json)

  # serialize weights to HDF5
  lst.save_weights(weightspath)
  print("Saved model to disk")

  # load json and create model
  json_file = open(filepath, 'r')
  loaded_model_json = json_file.read()
  json_file.close()
  lst = model_from_json(loaded_model_json)

  # load weights into new model
  lst.load_weights(weightspath)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
# load json and create model
json_file = open(filepath, 'r')
loaded_model_json = json_file.read()
json_file.close()
lst = model_from_json(loaded_model_json)

# load weights into new model
lst.load_weights(weightspath)
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
# defining loss function, optimizer, metrics and then compiling model
lst.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
# predicting target attribute on testing dataset
x_test = x_test.astype('float32')
y_test = y_test.astype('float32')

test_results = lst.evaluate(x_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')
# Out:
# 985/985 [==============================] - 3s 2ms/step - loss: 0.0644 - accuracy: 0.9777
# Test results - Loss: 0.06438589841127396 - Accuracy: 97.77417778968811%

# %%
# Plot of accuracy vs epoch of train and test dataset
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('plots/lstm_binary_accuracy.png')
plt.show()

# %%
# Plot of loss vs epoch of train and test dataset
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('plots/lstm_binary_loss.png')
plt.show()

# %%
# representation of model layers
plot_model(lst, to_file='plots/lstm_binary.png', show_shapes=True,)

# %%
y_test.shape
# Out:
# (31494, 1)

# %%
y_pred = lst.predict(x_test)
# Out:
# 985/985 [==============================] - 4s 3ms/step

# %%
y_pred.shape
# Out:
# (31494, 1)

# %%
from sklearn.metrics import roc_curve, auc as calculate_auc

y_pred = lst.predict(x_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = calculate_auc(fpr, tpr)  # Use the calculate_auc function from sklearn.metrics
# Out:
# 985/985 [==============================] - 2s 2ms/step

# %%
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Keras (area = {:.3f})'.format(roc_auc))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.savefig('plots/lstm_binary_roc.png')
plt.show()

# %%
y_classes = (lst.predict(x_test)>0.5).astype('int32')
# Out:
# 985/985 [==============================] - 2s 2ms/step

# %%
print("Recall Score - ",recall_score(y_test,y_classes))
print("F1 Score - ",f1_score(y_test,y_classes))
print("Precision Score - ",precision_score(y_test,y_classes))
# Out:
# Recall Score -  0.98634791939907
# F1 Score -  0.9792548311680626
# Precision Score -  0.9722630310865605

# %% [markdown]
# # **Multi Layer Perceptron Classifier (Binary Classification)**

# %%
X = bin_data.iloc[:,0:93].values # dataset excluding target attribute (encoded, one-hot-encoded,original)
Y = bin_data[['intrusion']].values # target attribute

# %%
# splitting the dataset 75% for training and 25% testing
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.25, random_state=42)

# %%
mlp = Sequential() # creating model

# adding input layer and first layer with 50 neurons
mlp.add(Dense(units=50, input_dim=X_train.shape[1], activation='relu'))
# output layer with sigmoid activation
mlp.add(Dense(units=1,activation='sigmoid'))

# %%
# defining loss function, optimizer, metrics and then compiling model
mlp.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# summary of model layers
mlp.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 50)                4700
#
#  dense_2 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 4751 (18.56 KB)
# Trainable params: 4751 (18.56 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# training the model on training dataset
X_train = X_train.astype('float32')
y_train = y_train.astype('float32')

history = mlp.fit(X_train, y_train, epochs=100, batch_size=5000,validation_split=0.2)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 2s 34ms/step - loss: 0.4246 - accuracy: 0.8983 - val_loss: 0.3272 - val_accuracy: 0.9234
# Epoch 2/100
# 16/16 [==============================] - 0s 16ms/step - loss: 0.2830 - accuracy: 0.9237 - val_loss: 0.2408 - val_accuracy: 0.9282
# Epoch 3/100
# 16/16 [==============================] - 0s 19ms/step - loss: 0.2200 - accuracy: 0.9340 - val_loss: 0.1990 - val_accuracy: 0.9446
# Epoch 4/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1858 - accuracy: 0.9456 - val_loss: 0.1739 - val_accuracy: 0.9508
# Epoch 5/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1642 - accuracy: 0.9553 - val_loss: 0.1569 - val_accuracy: 0.9599
# Epoch 6/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1491 - accuracy: 0.9604 - val_loss: 0.1446 - val_accuracy: 0.9627
# Epoch 7/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1381 - accuracy: 0.9628 - val_loss: 0.1354 - val_accuracy: 0.9645
# Epoch 8/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1297 - accuracy: 0.9660 - val_loss: 0.1281 - val_accuracy: 0.9662
# Epoch 9/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1231 - accuracy: 0.9670 - val_loss: 0.1223 - val_accuracy: 0.9670
# Epoch 10/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1177 - accuracy: 0.9676 - val_loss: 0.1173 - val_accuracy: 0.9681
# Epoch 11/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1131 - accuracy: 0.9688 - val_loss: 0.1131 - val_accuracy: 0.9690
# Epoch 12/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1092 - accuracy: 0.9696 - val_loss: 0.1094 - val_accuracy: 0.9693
# Epoch 13/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1057 - accuracy: 0.9699 - val_loss: 0.1062 - val_accuracy: 0.9696
# Epoch 14/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1027 - accuracy: 0.9701 - val_loss: 0.1033 - val_accuracy: 0.9698
# Epoch 15/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.1000 - accuracy: 0.9706 - val_loss: 0.1007 - val_accuracy: 0.9703
# Epoch 16/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0976 - accuracy: 0.9711 - val_loss: 0.0983 - val_accuracy: 0.9707
# Epoch 17/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0953 - accuracy: 0.9714 - val_loss: 0.0961 - val_accuracy: 0.9708
# Epoch 18/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0933 - accuracy: 0.9716 - val_loss: 0.0941 - val_accuracy: 0.9713
# Epoch 19/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0914 - accuracy: 0.9718 - val_loss: 0.0922 - val_accuracy: 0.9711
# Epoch 20/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0897 - accuracy: 0.9718 - val_loss: 0.0906 - val_accuracy: 0.9711
# Epoch 21/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0881 - accuracy: 0.9719 - val_loss: 0.0891 - val_accuracy: 0.9713
# Epoch 22/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0867 - accuracy: 0.9720 - val_loss: 0.0877 - val_accuracy: 0.9714
# Epoch 23/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0854 - accuracy: 0.9719 - val_loss: 0.0864 - val_accuracy: 0.9712
# Epoch 24/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0842 - accuracy: 0.9720 - val_loss: 0.0852 - val_accuracy: 0.9713
# Epoch 25/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0830 - accuracy: 0.9721 - val_loss: 0.0841 - val_accuracy: 0.9710
# Epoch 26/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0820 - accuracy: 0.9721 - val_loss: 0.0830 - val_accuracy: 0.9709
# Epoch 27/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0810 - accuracy: 0.9720 - val_loss: 0.0821 - val_accuracy: 0.9709
# Epoch 28/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0800 - accuracy: 0.9721 - val_loss: 0.0812 - val_accuracy: 0.9708
# Epoch 29/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0792 - accuracy: 0.9721 - val_loss: 0.0804 - val_accuracy: 0.9708
# Epoch 30/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0784 - accuracy: 0.9721 - val_loss: 0.0795 - val_accuracy: 0.9708
# Epoch 31/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0776 - accuracy: 0.9721 - val_loss: 0.0788 - val_accuracy: 0.9707
# Epoch 32/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0769 - accuracy: 0.9722 - val_loss: 0.0781 - val_accuracy: 0.9707
# Epoch 33/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0762 - accuracy: 0.9723 - val_loss: 0.0775 - val_accuracy: 0.9708
# Epoch 34/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0756 - accuracy: 0.9724 - val_loss: 0.0768 - val_accuracy: 0.9711
# Epoch 35/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0749 - accuracy: 0.9724 - val_loss: 0.0763 - val_accuracy: 0.9710
# Epoch 36/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0744 - accuracy: 0.9725 - val_loss: 0.0758 - val_accuracy: 0.9711
# Epoch 37/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0738 - accuracy: 0.9725 - val_loss: 0.0752 - val_accuracy: 0.9712
# Epoch 38/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0733 - accuracy: 0.9731 - val_loss: 0.0747 - val_accuracy: 0.9720
# Epoch 39/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0728 - accuracy: 0.9735 - val_loss: 0.0743 - val_accuracy: 0.9723
# Epoch 40/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0724 - accuracy: 0.9740 - val_loss: 0.0738 - val_accuracy: 0.9730
# Epoch 41/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0719 - accuracy: 0.9747 - val_loss: 0.0734 - val_accuracy: 0.9735
# Epoch 42/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0715 - accuracy: 0.9753 - val_loss: 0.0730 - val_accuracy: 0.9738
# Epoch 43/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0711 - accuracy: 0.9756 - val_loss: 0.0726 - val_accuracy: 0.9742
# Epoch 44/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0707 - accuracy: 0.9759 - val_loss: 0.0723 - val_accuracy: 0.9742
# Epoch 45/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0703 - accuracy: 0.9760 - val_loss: 0.0719 - val_accuracy: 0.9747
# Epoch 46/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0700 - accuracy: 0.9760 - val_loss: 0.0716 - val_accuracy: 0.9750
# Epoch 47/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0697 - accuracy: 0.9767 - val_loss: 0.0713 - val_accuracy: 0.9750
# Epoch 48/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0693 - accuracy: 0.9763 - val_loss: 0.0709 - val_accuracy: 0.9751
# Epoch 49/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0690 - accuracy: 0.9767 - val_loss: 0.0707 - val_accuracy: 0.9752
# Epoch 50/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0687 - accuracy: 0.9772 - val_loss: 0.0704 - val_accuracy: 0.9753
# Epoch 51/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0684 - accuracy: 0.9772 - val_loss: 0.0701 - val_accuracy: 0.9754
# Epoch 52/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0681 - accuracy: 0.9773 - val_loss: 0.0699 - val_accuracy: 0.9753
# Epoch 53/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0679 - accuracy: 0.9771 - val_loss: 0.0697 - val_accuracy: 0.9759
# Epoch 54/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0677 - accuracy: 0.9775 - val_loss: 0.0694 - val_accuracy: 0.9756
# Epoch 55/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0674 - accuracy: 0.9775 - val_loss: 0.0693 - val_accuracy: 0.9757
# Epoch 56/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0672 - accuracy: 0.9775 - val_loss: 0.0689 - val_accuracy: 0.9757
# Epoch 57/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0669 - accuracy: 0.9776 - val_loss: 0.0688 - val_accuracy: 0.9758
# Epoch 58/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0667 - accuracy: 0.9776 - val_loss: 0.0686 - val_accuracy: 0.9757
# Epoch 59/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0666 - accuracy: 0.9777 - val_loss: 0.0684 - val_accuracy: 0.9759
# Epoch 60/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0664 - accuracy: 0.9778 - val_loss: 0.0682 - val_accuracy: 0.9758
# Epoch 61/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0661 - accuracy: 0.9778 - val_loss: 0.0681 - val_accuracy: 0.9760
# Epoch 62/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0660 - accuracy: 0.9779 - val_loss: 0.0679 - val_accuracy: 0.9761
# Epoch 63/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0658 - accuracy: 0.9781 - val_loss: 0.0677 - val_accuracy: 0.9759
# Epoch 64/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0656 - accuracy: 0.9780 - val_loss: 0.0675 - val_accuracy: 0.9760
# Epoch 65/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0655 - accuracy: 0.9781 - val_loss: 0.0674 - val_accuracy: 0.9759
# Epoch 66/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0653 - accuracy: 0.9781 - val_loss: 0.0672 - val_accuracy: 0.9760
# Epoch 67/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0651 - accuracy: 0.9781 - val_loss: 0.0671 - val_accuracy: 0.9759
# Epoch 68/100
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0650 - accuracy: 0.9781 - val_loss: 0.0670 - val_accuracy: 0.9759
# Epoch 69/100
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0648 - accuracy: 0.9781 - val_loss: 0.0669 - val_accuracy: 0.9760
# Epoch 70/100
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0647 - accuracy: 0.9781 - val_loss: 0.0667 - val_accuracy: 0.9759
# Epoch 71/100
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0646 - accuracy: 0.9782 - val_loss: 0.0666 - val_accuracy: 0.9760
# Epoch 72/100
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0644 - accuracy: 0.9781 - val_loss: 0.0666 - val_accuracy: 0.9760
# Epoch 73/100
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0643 - accuracy: 0.9782 - val_loss: 0.0664 - val_accuracy: 0.9760
# Epoch 74/100
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0642 - accuracy: 0.9782 - val_loss: 0.0662 - val_accuracy: 0.9761
# Epoch 75/100
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0641 - accuracy: 0.9782 - val_loss: 0.0661 - val_accuracy: 0.9760
# Epoch 76/100
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0639 - accuracy: 0.9782 - val_loss: 0.0661 - val_accuracy: 0.9761
# Epoch 77/100
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0638 - accuracy: 0.9782 - val_loss: 0.0659 - val_accuracy: 0.9761
# Epoch 78/100
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0637 - accuracy: 0.9782 - val_loss: 0.0658 - val_accuracy: 0.9762
# Epoch 79/100
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0636 - accuracy: 0.9783 - val_loss: 0.0658 - val_accuracy: 0.9761
# Epoch 80/100
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0635 - accuracy: 0.9784 - val_loss: 0.0657 - val_accuracy: 0.9764
# Epoch 81/100
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0634 - accuracy: 0.9784 - val_loss: 0.0656 - val_accuracy: 0.9762
# Epoch 82/100
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0633 - accuracy: 0.9784 - val_loss: 0.0655 - val_accuracy: 0.9762
# Epoch 83/100
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0632 - accuracy: 0.9783 - val_loss: 0.0654 - val_accuracy: 0.9762
# Epoch 84/100
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0632 - accuracy: 0.9783 - val_loss: 0.0654 - val_accuracy: 0.9768
# Epoch 85/100
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0630 - accuracy: 0.9786 - val_loss: 0.0652 - val_accuracy: 0.9765
# Epoch 86/100
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0630 - accuracy: 0.9783 - val_loss: 0.0652 - val_accuracy: 0.9769
# Epoch 87/100
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0629 - accuracy: 0.9786 - val_loss: 0.0650 - val_accuracy: 0.9770
# Epoch 88/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0627 - accuracy: 0.9787 - val_loss: 0.0650 - val_accuracy: 0.9770
# Epoch 89/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0627 - accuracy: 0.9787 - val_loss: 0.0649 - val_accuracy: 0.9769
# Epoch 90/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0626 - accuracy: 0.9787 - val_loss: 0.0649 - val_accuracy: 0.9771
# Epoch 91/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0625 - accuracy: 0.9788 - val_loss: 0.0648 - val_accuracy: 0.9772
# Epoch 92/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0624 - accuracy: 0.9789 - val_loss: 0.0647 - val_accuracy: 0.9771
# Epoch 93/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0625 - accuracy: 0.9789 - val_loss: 0.0646 - val_accuracy: 0.9767
# Epoch 94/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0623 - accuracy: 0.9786 - val_loss: 0.0646 - val_accuracy: 0.9772
# Epoch 95/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0622 - accuracy: 0.9789 - val_loss: 0.0645 - val_accuracy: 0.9771
# Epoch 96/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0620 - accuracy: 0.9789 - val_loss: 0.0644 - val_accuracy: 0.9771
# Epoch 97/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0620 - accuracy: 0.9788 - val_loss: 0.0643 - val_accuracy: 0.9772
# Epoch 98/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.0620 - accuracy: 0.9789 - val_loss: 0.0643 - val_accuracy: 0.9772
# Epoch 99/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0618 - accuracy: 0.9790 - val_loss: 0.0642 - val_accuracy: 0.9769
# Epoch 100/100
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0618 - accuracy: 0.9787 - val_loss: 0.0642 - val_accuracy: 0.9773

# %%
filepath = './models/mlp_binary.json'
weightspath = './weights/mlp_binary.h5'
if (not path.isfile(filepath)):
  # serialize model to JSON
  mlp_json = mlp.to_json()
  with open(filepath, "w") as json_file:
    json_file.write(mlp_json)

  # serialize weights to HDF5
  mlp.save_weights(weightspath)
  print("Saved model to disk")

  # load json and create model
  json_file = open(filepath, 'r')
  loaded_model_json = json_file.read()
  json_file.close()
  mlp = model_from_json(loaded_model_json)

  # load weights into new model
  mlp.load_weights(weightspath)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
# defining loss function, optimizer, metrics and then compiling model
mlp.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# predicting target attribute on testing dataset
X_test = X_test.astype('float32')
y_test = y_test.astype('float32')

test_results = mlp.evaluate(X_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}')
# Out:
# 985/985 [==============================] - 2s 1ms/step - loss: 0.0627 - accuracy: 0.9784
# Test results - Loss: 0.0627031922340393 - Accuracy: 97.84403443336487

# %%
# Plot of accuracy vs epoch of train and test dataset
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('plots/mlp_binary_accuracy.png')
plt.show()

# %%
# Plot of loss vs epoch of train and test dataset
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Plot of loss vs epoch for train and test dataset')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('plots/mlp_binary_loss.png')
plt.show()

# %%
plot_model(mlp, to_file='plots/mlp_binary.png', show_shapes=True,)

# %%
y_pred = mlp.predict(X_test).ravel()
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc = auc(fpr, tpr)
# Out:
# 985/985 [==============================] - 1s 1ms/step

# %%
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Keras (area = {:.3f})'.format(auc))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.savefig('plots/mlp_binary_roc.png')
plt.show()

# %%
pred = mlp.predict(X_test)
y_classes = (mlp.predict(X_test)>0.5).astype('int32')
# Out:
# 985/985 [==============================] - 1s 1ms/step
# 985/985 [==============================] - 2s 2ms/step

# %%
print("Recall Score - ",recall_score(y_test,y_classes))
print("F1 Score - ",f1_score(y_test,y_classes))
print("Precision Score - ",precision_score(y_test,y_classes))
# Out:
# Recall Score -  0.9874210087039466
# F1 Score -  0.9799142138736874
# Precision Score -  0.9725206975515237

# %% [markdown]
# # **Multi Layer Perceptron Classifier (Multi-class Classification)**

# %%
X = multi_data.iloc[:,0:93]  # dataset excluding target attribute (encoded, one-hot-encoded,original)
Y = multi_data[['Dos','normal','Probe','R2L','U2R']] # target attributes

# %%
# splitting the dataset 75% for training and 25% testing
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.25, random_state=42)

# %%
mlp = Sequential() # initializing model
# input layer and first layer with 50 neurons
mlp.add(Dense(units=50, input_dim=X_train.shape[1], activation='relu'))
# output layer with softmax activation
mlp.add(Dense(units=5,activation='softmax'))

# %%
# defining loss function, optimizer, metrics and then compiling model
mlp.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# summary of model layers
mlp.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 50)                4700
#
#  dense_4 (Dense)             (None, 5)                 255
#
# =================================================================
# Total params: 4955 (19.36 KB)
# Trainable params: 4955 (19.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# training the model on training dataset
X_train = X_train.astype('float32')
y_train = y_train.astype('float32')

history = mlp.fit(X_train, y_train, epochs=100, batch_size=5000,validation_split=0.2)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 1s 24ms/step - loss: 1.3471 - accuracy: 0.4894 - val_loss: 1.0461 - val_accuracy: 0.7791
# Epoch 2/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.8675 - accuracy: 0.8390 - val_loss: 0.6897 - val_accuracy: 0.8727
# Epoch 3/100
# 16/16 [==============================] - 0s 14ms/step - loss: 0.5938 - accuracy: 0.8895 - val_loss: 0.5005 - val_accuracy: 0.9033
# Epoch 4/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4492 - accuracy: 0.9018 - val_loss: 0.4000 - val_accuracy: 0.9051
# Epoch 5/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3709 - accuracy: 0.9046 - val_loss: 0.3434 - val_accuracy: 0.9090
# Epoch 6/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.3246 - accuracy: 0.9107 - val_loss: 0.3081 - val_accuracy: 0.9155
# Epoch 7/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.2941 - accuracy: 0.9151 - val_loss: 0.2832 - val_accuracy: 0.9206
# Epoch 8/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.2717 - accuracy: 0.9206 - val_loss: 0.2642 - val_accuracy: 0.9258
# Epoch 9/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2541 - accuracy: 0.9258 - val_loss: 0.2486 - val_accuracy: 0.9291
# Epoch 10/100
# 16/16 [==============================] - 0s 10ms/step - loss: 0.2395 - accuracy: 0.9298 - val_loss: 0.2354 - val_accuracy: 0.9322
# Epoch 11/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.2270 - accuracy: 0.9325 - val_loss: 0.2238 - val_accuracy: 0.9336
# Epoch 12/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.2158 - accuracy: 0.9352 - val_loss: 0.2132 - val_accuracy: 0.9373
# Epoch 13/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.2058 - accuracy: 0.9379 - val_loss: 0.2040 - val_accuracy: 0.9399
# Epoch 14/100
# 16/16 [==============================] - 0s 18ms/step - loss: 0.1969 - accuracy: 0.9425 - val_loss: 0.1958 - val_accuracy: 0.9459
# Epoch 15/100
# 16/16 [==============================] - 0s 20ms/step - loss: 0.1891 - accuracy: 0.9471 - val_loss: 0.1884 - val_accuracy: 0.9469
# Epoch 16/100
# 16/16 [==============================] - 0s 20ms/step - loss: 0.1824 - accuracy: 0.9479 - val_loss: 0.1819 - val_accuracy: 0.9477
# Epoch 17/100
# 16/16 [==============================] - 0s 19ms/step - loss: 0.1764 - accuracy: 0.9486 - val_loss: 0.1764 - val_accuracy: 0.9486
# Epoch 18/100
# 16/16 [==============================] - 0s 21ms/step - loss: 0.1712 - accuracy: 0.9496 - val_loss: 0.1713 - val_accuracy: 0.9501
# Epoch 19/100
# 16/16 [==============================] - 0s 19ms/step - loss: 0.1665 - accuracy: 0.9503 - val_loss: 0.1667 - val_accuracy: 0.9503
# Epoch 20/100
# 16/16 [==============================] - 0s 20ms/step - loss: 0.1623 - accuracy: 0.9503 - val_loss: 0.1625 - val_accuracy: 0.9502
# Epoch 21/100
# 16/16 [==============================] - 0s 21ms/step - loss: 0.1584 - accuracy: 0.9504 - val_loss: 0.1587 - val_accuracy: 0.9505
# Epoch 22/100
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1550 - accuracy: 0.9507 - val_loss: 0.1553 - val_accuracy: 0.9506
# Epoch 23/100
# 16/16 [==============================] - 0s 19ms/step - loss: 0.1518 - accuracy: 0.9512 - val_loss: 0.1521 - val_accuracy: 0.9515
# Epoch 24/100
# 16/16 [==============================] - 0s 20ms/step - loss: 0.1489 - accuracy: 0.9513 - val_loss: 0.1491 - val_accuracy: 0.9516
# Epoch 25/100
# 16/16 [==============================] - 0s 19ms/step - loss: 0.1461 - accuracy: 0.9518 - val_loss: 0.1464 - val_accuracy: 0.9522
# Epoch 26/100
# 16/16 [==============================] - 0s 20ms/step - loss: 0.1436 - accuracy: 0.9525 - val_loss: 0.1439 - val_accuracy: 0.9523
# Epoch 27/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.1413 - accuracy: 0.9526 - val_loss: 0.1415 - val_accuracy: 0.9524
# Epoch 28/100
# 16/16 [==============================] - 0s 18ms/step - loss: 0.1390 - accuracy: 0.9531 - val_loss: 0.1393 - val_accuracy: 0.9529
# Epoch 29/100
# 16/16 [==============================] - 0s 18ms/step - loss: 0.1369 - accuracy: 0.9529 - val_loss: 0.1371 - val_accuracy: 0.9530
# Epoch 30/100
# 16/16 [==============================] - 0s 21ms/step - loss: 0.1350 - accuracy: 0.9532 - val_loss: 0.1353 - val_accuracy: 0.9538
# Epoch 31/100
# 16/16 [==============================] - 0s 17ms/step - loss: 0.1331 - accuracy: 0.9538 - val_loss: 0.1334 - val_accuracy: 0.9539
# Epoch 32/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1313 - accuracy: 0.9540 - val_loss: 0.1317 - val_accuracy: 0.9539
# Epoch 33/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1297 - accuracy: 0.9542 - val_loss: 0.1302 - val_accuracy: 0.9538
# Epoch 34/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1282 - accuracy: 0.9546 - val_loss: 0.1285 - val_accuracy: 0.9543
# Epoch 35/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1267 - accuracy: 0.9554 - val_loss: 0.1271 - val_accuracy: 0.9555
# Epoch 36/100
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1253 - accuracy: 0.9555 - val_loss: 0.1257 - val_accuracy: 0.9553
# Epoch 37/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1240 - accuracy: 0.9563 - val_loss: 0.1244 - val_accuracy: 0.9559
# Epoch 38/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1226 - accuracy: 0.9568 - val_loss: 0.1231 - val_accuracy: 0.9566
# Epoch 39/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1214 - accuracy: 0.9570 - val_loss: 0.1219 - val_accuracy: 0.9566
# Epoch 40/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1201 - accuracy: 0.9572 - val_loss: 0.1206 - val_accuracy: 0.9571
# Epoch 41/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1189 - accuracy: 0.9584 - val_loss: 0.1194 - val_accuracy: 0.9579
# Epoch 42/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1178 - accuracy: 0.9590 - val_loss: 0.1183 - val_accuracy: 0.9583
# Epoch 43/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1166 - accuracy: 0.9591 - val_loss: 0.1172 - val_accuracy: 0.9586
# Epoch 44/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1155 - accuracy: 0.9593 - val_loss: 0.1162 - val_accuracy: 0.9593
# Epoch 45/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1144 - accuracy: 0.9599 - val_loss: 0.1151 - val_accuracy: 0.9594
# Epoch 46/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1134 - accuracy: 0.9600 - val_loss: 0.1141 - val_accuracy: 0.9597
# Epoch 47/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1124 - accuracy: 0.9604 - val_loss: 0.1131 - val_accuracy: 0.9606
# Epoch 48/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1114 - accuracy: 0.9606 - val_loss: 0.1123 - val_accuracy: 0.9608
# Epoch 49/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1105 - accuracy: 0.9611 - val_loss: 0.1114 - val_accuracy: 0.9615
# Epoch 50/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1097 - accuracy: 0.9619 - val_loss: 0.1106 - val_accuracy: 0.9624
# Epoch 51/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1088 - accuracy: 0.9622 - val_loss: 0.1097 - val_accuracy: 0.9621
# Epoch 52/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1080 - accuracy: 0.9626 - val_loss: 0.1089 - val_accuracy: 0.9628
# Epoch 53/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1072 - accuracy: 0.9627 - val_loss: 0.1082 - val_accuracy: 0.9633
# Epoch 54/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1064 - accuracy: 0.9634 - val_loss: 0.1073 - val_accuracy: 0.9639
# Epoch 55/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1056 - accuracy: 0.9638 - val_loss: 0.1066 - val_accuracy: 0.9641
# Epoch 56/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1048 - accuracy: 0.9642 - val_loss: 0.1059 - val_accuracy: 0.9644
# Epoch 57/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1041 - accuracy: 0.9648 - val_loss: 0.1052 - val_accuracy: 0.9648
# Epoch 58/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1034 - accuracy: 0.9650 - val_loss: 0.1046 - val_accuracy: 0.9648
# Epoch 59/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1028 - accuracy: 0.9656 - val_loss: 0.1039 - val_accuracy: 0.9649
# Epoch 60/100
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1021 - accuracy: 0.9655 - val_loss: 0.1033 - val_accuracy: 0.9653
# Epoch 61/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1015 - accuracy: 0.9658 - val_loss: 0.1027 - val_accuracy: 0.9654
# Epoch 62/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1008 - accuracy: 0.9661 - val_loss: 0.1021 - val_accuracy: 0.9657
# Epoch 63/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.1002 - accuracy: 0.9666 - val_loss: 0.1016 - val_accuracy: 0.9658
# Epoch 64/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0996 - accuracy: 0.9667 - val_loss: 0.1011 - val_accuracy: 0.9659
# Epoch 65/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0991 - accuracy: 0.9671 - val_loss: 0.1005 - val_accuracy: 0.9665
# Epoch 66/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0986 - accuracy: 0.9673 - val_loss: 0.1001 - val_accuracy: 0.9666
# Epoch 67/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0980 - accuracy: 0.9673 - val_loss: 0.0997 - val_accuracy: 0.9664
# Epoch 68/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0975 - accuracy: 0.9677 - val_loss: 0.0991 - val_accuracy: 0.9669
# Epoch 69/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0971 - accuracy: 0.9679 - val_loss: 0.0987 - val_accuracy: 0.9669
# Epoch 70/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0966 - accuracy: 0.9680 - val_loss: 0.0983 - val_accuracy: 0.9671
# Epoch 71/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0961 - accuracy: 0.9678 - val_loss: 0.0979 - val_accuracy: 0.9673
# Epoch 72/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0956 - accuracy: 0.9681 - val_loss: 0.0975 - val_accuracy: 0.9675
# Epoch 73/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0952 - accuracy: 0.9684 - val_loss: 0.0970 - val_accuracy: 0.9674
# Epoch 74/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0948 - accuracy: 0.9682 - val_loss: 0.0968 - val_accuracy: 0.9675
# Epoch 75/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0944 - accuracy: 0.9686 - val_loss: 0.0962 - val_accuracy: 0.9677
# Epoch 76/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0940 - accuracy: 0.9685 - val_loss: 0.0958 - val_accuracy: 0.9679
# Epoch 77/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0935 - accuracy: 0.9685 - val_loss: 0.0955 - val_accuracy: 0.9679
# Epoch 78/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0931 - accuracy: 0.9688 - val_loss: 0.0953 - val_accuracy: 0.9680
# Epoch 79/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0928 - accuracy: 0.9689 - val_loss: 0.0947 - val_accuracy: 0.9679
# Epoch 80/100
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0925 - accuracy: 0.9698 - val_loss: 0.0945 - val_accuracy: 0.9682
# Epoch 81/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0921 - accuracy: 0.9693 - val_loss: 0.0940 - val_accuracy: 0.9680
# Epoch 82/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0917 - accuracy: 0.9693 - val_loss: 0.0939 - val_accuracy: 0.9682
# Epoch 83/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0914 - accuracy: 0.9693 - val_loss: 0.0935 - val_accuracy: 0.9684
# Epoch 84/100
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0911 - accuracy: 0.9693 - val_loss: 0.0934 - val_accuracy: 0.9687
# Epoch 85/100
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0908 - accuracy: 0.9699 - val_loss: 0.0929 - val_accuracy: 0.9684
# Epoch 86/100
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0904 - accuracy: 0.9696 - val_loss: 0.0928 - val_accuracy: 0.9689
# Epoch 87/100
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0902 - accuracy: 0.9698 - val_loss: 0.0923 - val_accuracy: 0.9685
# Epoch 88/100
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0899 - accuracy: 0.9697 - val_loss: 0.0922 - val_accuracy: 0.9688
# Epoch 89/100
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0895 - accuracy: 0.9700 - val_loss: 0.0919 - val_accuracy: 0.9687
# Epoch 90/100
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0892 - accuracy: 0.9703 - val_loss: 0.0916 - val_accuracy: 0.9693
# Epoch 91/100
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0890 - accuracy: 0.9704 - val_loss: 0.0913 - val_accuracy: 0.9697
# Epoch 92/100
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0887 - accuracy: 0.9705 - val_loss: 0.0912 - val_accuracy: 0.9691
# Epoch 93/100
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0885 - accuracy: 0.9706 - val_loss: 0.0909 - val_accuracy: 0.9694
# Epoch 94/100
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0882 - accuracy: 0.9707 - val_loss: 0.0905 - val_accuracy: 0.9697
# Epoch 95/100
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0879 - accuracy: 0.9707 - val_loss: 0.0905 - val_accuracy: 0.9698
# Epoch 96/100
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0877 - accuracy: 0.9710 - val_loss: 0.0901 - val_accuracy: 0.9700
# Epoch 97/100
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0875 - accuracy: 0.9711 - val_loss: 0.0901 - val_accuracy: 0.9698
# Epoch 98/100
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0873 - accuracy: 0.9710 - val_loss: 0.0896 - val_accuracy: 0.9701
# Epoch 99/100
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0870 - accuracy: 0.9711 - val_loss: 0.0896 - val_accuracy: 0.9699
# Epoch 100/100
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0869 - accuracy: 0.9713 - val_loss: 0.0895 - val_accuracy: 0.9701

# %%
filepath = './models/mlp_multi.json'
weightspath = './weights/mlp_multi.h5'
if (not path.isfile(filepath)):
  # serialize model to JSON
  mlp_json = mlp.to_json()
  with open(filepath, "w") as json_file:
    json_file.write(mlp_json)

  # serialize weights to HDF5
  mlp.save_weights(weightspath)
  print("Saved model to disk")

  # load json and create model
  json_file = open(filepath, 'r')
  loaded_model_json = json_file.read()
  json_file.close()
  mlp = model_from_json(loaded_model_json)

  # load weights into new model
  mlp.load_weights(weightspath)
  print("Loaded model from disk")
# Out:
# Saved model to disk
# Loaded model from disk

# %%
# defining loss function, optimizer, metrics and then compiling model
mlp.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# predicting target attribute on testing dataset
X_test = X_test.astype('float32')
y_test = y_test.astype('float32')

test_results = mlp.evaluate(X_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')
# Out:
# 985/985 [==============================] - 2s 1ms/step - loss: 0.0895 - accuracy: 0.9703
# Test results - Loss: 0.08953168988227844 - Accuracy: 97.034353017807%

# %%
# Plot of accuracy vs epoch for train and test dataset
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.savefig('plots/mlp_multi_accuracy.png')
plt.show()

# %%
# Plot of loss vs epoch for train and test dataset
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.savefig('plots/mlp_multi_loss.png')
plt.show()

# %%
# representation of model layers
plot_model(mlp, to_file='plots/mlp_multi.png', show_shapes=True,)

# %%
n_classes = len(le2.classes_)
n_classes
# Out:
# 5

# %%
y_pred = mlp.predict(X_test)
# Out:
# 985/985 [==============================] - 1s 1ms/step

# %%
fpr_mlp = dict()
tpr_mlp = dict()
roc_auc_mlp = dict()
for i in range(n_classes):
    fpr_mlp[i], tpr_mlp[i], _ = roc_curve(y_test.iloc[:, i], y_pred[:, i])
    roc_auc_mlp[i] = calculate_auc(fpr_mlp[i], tpr_mlp[i])  # Use a different variable name for AUC calculation

# %%
for i in range(n_classes):
  plt.plot([0, 1], [0, 1], 'k--')
  plt.plot(fpr_mlp[i], tpr_mlp[i], label='Keras (area = {:.3f})'.format(roc_auc_mlp[i]))
  plt.xlabel('False positive rate')
  plt.ylabel('True positive rate')
  plt.title('ROC curve')
  plt.legend(loc='best')
  plt.savefig('plots/mlp_multi_roc'+str(i)+'.png')
  plt.show()

# %%
pred = mlp.predict(X_test)
# Out:
# 985/985 [==============================] - 2s 2ms/step

# %%
for j in range(0,pred.shape[1]):
  for i in range(0,pred.shape[0]):
    pred[i][j] = int(round(pred[i][j]))

# %%
pred_df = pd.DataFrame(pred,columns=y_test.columns)

# %%
print("Recall Score - ",recall_score(y_test,pred_df.astype('uint8'),average='micro'))
print("F1 Score - ",f1_score(y_test,pred_df.astype('uint8'),average='micro'))
print("Precision Score - ",precision_score(y_test,pred_df.astype('uint8'),average='micro'))
# Out:
# Recall Score -  0.9683114243982981
# F1 Score -  0.9699745547073791
# Precision Score -  0.9716434078888676

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score, f1_score, precision_score
from keras.models import model_from_json

# Load the preprocessed binary dataset
bin_data = pd.read_csv('./datasets/bin_data_testC.csv')
bin_data = bin_data.iloc[:, 1:]

X = bin_data.iloc[:, 0:93]
Y = bin_data[['intrusion']]

X = X.to_numpy()
X = np.reshape(X, (X.shape[0], 1, X.shape[1]))

filepath = './models/lst_binary.json'
weightspath = './weights/lst_binary.h5'

with open(filepath, 'r') as json_file:
    loaded_model_json = json_file.read()
lst = model_from_json(loaded_model_json)

# Load weights into the model
lst.load_weights(weightspath)
print("Loaded model from disk")

# Compile the model
lst.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Ensure the data types are correct
X_test = X.astype('float32')
y_test = Y.astype('float32')

test_results = lst.evaluate(X_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1] * 100}%')
y_pred = (lst.predict(X_test) > 0.5).astype('int32')
print("Recall Score - ", recall_score(y_test, y_pred))
print("F1 Score - ", f1_score(y_test, y_pred))
print("Precision Score - ", precision_score(y_test, y_pred))
# Out:
# Loaded model from disk
# 705/705 [==============================] - 2s 2ms/step - loss: 0.8580 - accuracy: 0.7771
# Test results - Loss: 0.8579802513122559 - Accuracy: 77.71469354629517%
# 705/705 [==============================] - 2s 2ms/step
# Recall Score -  0.9186489547935331
# F1 Score -  0.7802851395084406
# Precision Score -  0.6781451919422273

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import recall_score, f1_score, precision_score
from keras.models import model_from_json

# Load the preprocessed binary dataset
bin_data = pd.read_csv('./datasets/bin_data_testC.csv')
bin_data = bin_data.iloc[:, 1:]

X = bin_data.iloc[:, 0:93]
Y = bin_data[['intrusion']]

filepath = './models/mlp_binary.json'
weightspath = './weights/mlp_binary.h5'

with open(filepath, 'r') as json_file:
    loaded_model_json = json_file.read()
mlp = model_from_json(loaded_model_json)

mlp.load_weights(weightspath)
print("Loaded model from disk")

# Compile the model
mlp.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

X_test = X.astype('float32')
y_test = Y.astype('float32')

# Evaluate the model
test_results = mlp.evaluate(X_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1] * 100}%')

# Make predictions
y_pred = (mlp.predict(X_test) > 0.5).astype('int32')

# Calculate and print evaluation metrics
print("Recall Score - ", recall_score(y_test, y_pred))
print("F1 Score - ", f1_score(y_test, y_pred))
print("Precision Score - ", precision_score(y_test, y_pred))
# Out:
# Loaded model from disk
# 705/705 [==============================] - 2s 2ms/step - loss: 0.7785 - accuracy: 0.7728
# Test results - Loss: 0.7785344123840332 - Accuracy: 77.27998495101929%
# 705/705 [==============================] - 2s 2ms/step
# Recall Score -  0.9220471630110184
# F1 Score -  0.777594442032132
# Precision Score -  0.672272693145131

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import recall_score, f1_score, precision_score
from keras.models import model_from_json

multi_data = pd.read_csv('./datasets/multi_data_testC.csv')
multi_data = multi_data.iloc[:, 1:]
X = multi_data.iloc[:,0:93]
Y = multi_data[['Dos','normal','Probe','R2L','U2R']] # target attributes
filepath = './models/mlp_multi.json'
weightspath = './weights/mlp_multi.h5'

with open(filepath, 'r') as json_file:
    loaded_model_json = json_file.read()
mlp = model_from_json(loaded_model_json)

mlp.load_weights(weightspath)
mlp.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
X_test = X.astype('float32')
y_test = Y.astype('float32')

test_results = mlp.evaluate(X_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')
pred = mlp.predict(X_test)

for j in range(0,pred.shape[1]):
  for i in range(0,pred.shape[0]):
    pred[i][j] = int(round(pred[i][j]))

pred_df = pd.DataFrame(pred,columns=y_test.columns)

print("Recall Score - ",recall_score(y_test,pred_df.astype('uint8'),average='micro'))
print("F1 Score - ",f1_score(y_test,pred_df.astype('uint8'),average='micro'))
print("Precision Score - ",precision_score(y_test,pred_df.astype('uint8'),average='micro'))
# Out:
# 705/705 [==============================] - 1s 1ms/step - loss: 1.3206 - accuracy: 0.7464
# Test results - Loss: 1.3206396102905273 - Accuracy: 74.63626861572266%
# 705/705 [==============================] - 1s 1ms/step
# Recall Score -  0.7392654364797729
# F1 Score -  0.7452988395232878
# Precision Score -  0.7514315343342802
